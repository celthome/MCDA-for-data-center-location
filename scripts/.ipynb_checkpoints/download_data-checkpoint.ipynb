# %% [markdown]
# # Download the data
# ## Download power lines

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, box, GeometryCollection
from ohsome import OhsomeClient
import matplotlib.pyplot as plt

client = OhsomeClient()

# Load the geojson file with geopandas
bpolys = gpd.read_file("../data/input/baden_wuerttemberg.geojson")

# Define which OSM features should be considered for power lines.
filter_power_lines = "power=line"

# Specify the geometry type you want to retrieve (LineString for power lines)
geometry_type_power_lines = "LineString"

# Make the request to ohsome API for power lines
response_power_lines = client.elements.geometry.post(
    bpolys=bpolys,
    filter=filter_power_lines,
    properties="tags,metadata"
)

# Convert the response to a GeoDataFrame for power lines
power_lines_df = response_power_lines.as_dataframe()

# Display and plot the power lines GeoDataFrame
display(power_lines_df)
ax = power_lines_df.plot()

# Save the plot to a file using fig.savefig()
fig = ax.get_figure()
fig.savefig("../plots/powerlines.png", dpi=300, bbox_inches="tight")

# Save the power lines GeoDataFrame to a GeoJSON file
power_lines_df.to_file("../data/output/powerlines.geojson", driver='GeoJSON')
# Out:
#                                                                                geometry  \
# @osmId           @snapshotTimestamp
# relation/3883861 2024-03-19 14:00:00  GEOMETRYCOLLECTION (POLYGON ((9.88442 48.30252...
# way/1000343502   2024-03-19 14:00:00  LINESTRING (8.81531 48.37872, 8.81114 48.37861...
# way/1000343503   2024-03-19 14:00:00  LINESTRING (8.80334 48.37848, 8.79739 48.37626...
# way/100053588    2024-03-19 14:00:00  LINESTRING (8.20862 48.11473, 8.20771 48.11510...
# way/100551356    2024-03-19 14:00:00  LINESTRING (9.07576 48.11526, 9.07732 48.11282...
# ...                                                                                 ...
# way/993243194    2024-03-19 14:00:00    LINESTRING (8.44141 49.25012, 8.44136 49.25016)
# way/993243195    2024-03-19 14:00:00    LINESTRING (8.44086 49.25054, 8.44090 49.25049)
# way/993243196    2024-03-19 14:00:00    LINESTRING (8.44075 49.24984, 8.44070 49.24989)
# way/993243198    2024-03-19 14:00:00    LINESTRING (8.44108 49.25063, 8.44112 49.25059)
# way/993243206    2024-03-19 14:00:00    LINESTRING (8.44068 49.25040, 8.44064 49.25045)
#
#                                       @changesetId             @lastEdit  \
# @osmId           @snapshotTimestamp
# relation/3883861 2024-03-19 14:00:00     131248587  2023-01-13T23:23:19Z
# way/1000343502   2024-03-19 14:00:00     139299744  2023-08-01T13:05:27Z
# way/1000343503   2024-03-19 14:00:00     143354035  2023-10-30T09:24:09Z
# way/100053588    2024-03-19 14:00:00     137650969  2023-06-22T14:46:52Z
# way/100551356    2024-03-19 14:00:00     138415167  2023-07-12T09:57:37Z
# ...                                            ...                   ...
# way/993243194    2024-03-19 14:00:00     112575255  2021-10-16T11:36:50Z
# way/993243195    2024-03-19 14:00:00     112575255  2021-10-16T11:36:50Z
# way/993243196    2024-03-19 14:00:00     112575255  2021-10-16T11:36:50Z
# way/993243198    2024-03-19 14:00:00     112575255  2021-10-16T11:36:50Z
# way/993243206    2024-03-19 14:00:00     112575255  2021-10-16T11:36:50Z
#
#                                       @osmType  @version cables frequency  \
# @osmId           @snapshotTimestamp
# relation/3883861 2024-03-19 14:00:00  relation         6      3        50
# way/1000343502   2024-03-19 14:00:00       way         2     12        50
# way/1000343503   2024-03-19 14:00:00       way         2     12       NaN
# way/100053588    2024-03-19 14:00:00       way        13      6       NaN
# way/100551356    2024-03-19 14:00:00       way        14      6       NaN
# ...                                        ...       ...    ...       ...
# way/993243194    2024-03-19 14:00:00       way         1      3        50
# way/993243195    2024-03-19 14:00:00       way         1      3        50
# way/993243196    2024-03-19 14:00:00       way         1      3        50
# way/993243198    2024-03-19 14:00:00       way         1      3        50
# way/993243206    2024-03-19 14:00:00       way         1      3        50
#
#                                                from                      name  \
# @osmId           @snapshotTimestamp
# relation/3883861 2024-03-19 14:00:00  Dellmensingen  Delmensingen - Rotensohl
# way/1000343502   2024-03-19 14:00:00            NaN                       NaN
# way/1000343503   2024-03-19 14:00:00            NaN                       NaN
# way/100053588    2024-03-19 14:00:00            NaN                       NaN
# way/100551356    2024-03-19 14:00:00            NaN               Anlage 1852
# ...                                             ...                       ...
# way/993243194    2024-03-19 14:00:00            NaN                       NaN
# way/993243195    2024-03-19 14:00:00            NaN                       NaN
# way/993243196    2024-03-19 14:00:00            NaN                       NaN
# way/993243198    2024-03-19 14:00:00            NaN                       NaN
# way/993243206    2024-03-19 14:00:00            NaN                       NaN
#
#                                      power  ... note_2 circuit:diff:names  \
# @osmId           @snapshotTimestamp         ...
# relation/3883861 2024-03-19 14:00:00  line  ...    NaN                NaN
# way/1000343502   2024-03-19 14:00:00  line  ...    NaN                NaN
# way/1000343503   2024-03-19 14:00:00  line  ...    NaN                NaN
# way/100053588    2024-03-19 14:00:00  line  ...    NaN                NaN
# way/100551356    2024-03-19 14:00:00  line  ...    NaN                NaN
# ...                                    ...  ...    ...                ...
# way/993243194    2024-03-19 14:00:00  line  ...    NaN                NaN
# way/993243195    2024-03-19 14:00:00  line  ...    NaN                NaN
# way/993243196    2024-03-19 14:00:00  line  ...    NaN                NaN
# way/993243198    2024-03-19 14:00:00  line  ...    NaN                NaN
# way/993243206    2024-03-19 14:00:00  line  ...    NaN                NaN
#
#                                      circuit:est_names source:cables  \
# @osmId           @snapshotTimestamp
# relation/3883861 2024-03-19 14:00:00               NaN           NaN
# way/1000343502   2024-03-19 14:00:00               NaN           NaN
# way/1000343503   2024-03-19 14:00:00               NaN           NaN
# way/100053588    2024-03-19 14:00:00               NaN           NaN
# way/100551356    2024-03-19 14:00:00               NaN           NaN
# ...                                                ...           ...
# way/993243194    2024-03-19 14:00:00               NaN           NaN
# way/993243195    2024-03-19 14:00:00               NaN           NaN
# way/993243196    2024-03-19 14:00:00               NaN           NaN
# way/993243198    2024-03-19 14:00:00               NaN           NaN
# way/993243206    2024-03-19 14:00:00               NaN           NaN
#
#                                      wikipedia circuit:layer note:de  \
# @osmId           @snapshotTimestamp
# relation/3883861 2024-03-19 14:00:00       NaN           NaN     NaN
# way/1000343502   2024-03-19 14:00:00       NaN           NaN     NaN
# way/1000343503   2024-03-19 14:00:00       NaN           NaN     NaN
# way/100053588    2024-03-19 14:00:00       NaN           NaN     NaN
# way/100551356    2024-03-19 14:00:00       NaN           NaN     NaN
# ...                                        ...           ...     ...
# way/993243194    2024-03-19 14:00:00       NaN           NaN     NaN
# way/993243195    2024-03-19 14:00:00       NaN           NaN     NaN
# way/993243196    2024-03-19 14:00:00       NaN           NaN     NaN
# way/993243198    2024-03-19 14:00:00       NaN           NaN     NaN
# way/993243206    2024-03-19 14:00:00       NaN           NaN     NaN
#
#                                      circuit:endpoint:busbar source:ref  \
# @osmId           @snapshotTimestamp
# relation/3883861 2024-03-19 14:00:00                     NaN        NaN
# way/1000343502   2024-03-19 14:00:00                     NaN        NaN
# way/1000343503   2024-03-19 14:00:00                     NaN        NaN
# way/100053588    2024-03-19 14:00:00                     NaN        NaN
# way/100551356    2024-03-19 14:00:00                     NaN        NaN
# ...                                                      ...        ...
# way/993243194    2024-03-19 14:00:00                     NaN        NaN
# way/993243195    2024-03-19 14:00:00                     NaN        NaN
# way/993243196    2024-03-19 14:00:00                     NaN        NaN
# way/993243198    2024-03-19 14:00:00                     NaN        NaN
# way/993243206    2024-03-19 14:00:00                     NaN        NaN
#
#                                      construction
# @osmId           @snapshotTimestamp
# relation/3883861 2024-03-19 14:00:00          NaN
# way/1000343502   2024-03-19 14:00:00          NaN
# way/1000343503   2024-03-19 14:00:00          yes
# way/100053588    2024-03-19 14:00:00          NaN
# way/100551356    2024-03-19 14:00:00          NaN
# ...                                           ...
# way/993243194    2024-03-19 14:00:00          NaN
# way/993243195    2024-03-19 14:00:00          NaN
# way/993243196    2024-03-19 14:00:00          NaN
# way/993243198    2024-03-19 14:00:00          NaN
# way/993243206    2024-03-19 14:00:00          NaN
#
# [5204 rows x 86 columns]

# %% [markdown]
# ## Download power plants

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, box, GeometryCollection
from ohsome import OhsomeClient
import matplotlib.pyplot as plt

client = OhsomeClient()

# Load the geojson file with geopandas
bpolys = gpd.read_file("../data/input/baden_wuerttemberg.geojson")

# Define which OSM features should be considered for power plants.
filter_power_plant = "power=plant"

# Make the request to ohsome API for power plants
response_power_plant = client.elements.geometry.post(
    bpolys=bpolys,
    filter=filter_power_plant,
    properties="tags,metadata"
)

# Convert the response to a GeoDataFrame for power plants
power_plant_df = response_power_plant.as_dataframe()

# Reproject to EPSG 25832 (ETRS89 / UTM Zone 32N)
bpolys = bpolys.to_crs(epsg=25832)
power_plant_df = power_plant_df.to_crs(epsg=25832)

# Some Features (very less) are points but most of them are polygons. 
# So we buffer the points to faciliate further calculations.
# Define a function to create squares around each point or within a GeometryCollection
def create_square_around_geometry(geometry, side_length):
    if isinstance(geometry, Point):
        x, y = geometry.x, geometry.y
        half_side = side_length / 2
        return box(x - half_side, y - half_side, x + half_side, y + half_side)
    elif isinstance(geometry, GeometryCollection):
        return GeometryCollection([create_square_around_geometry(sub_geometry, side_length) for sub_geometry in geometry.geoms])
    else:
        return geometry  # For other geometry types, return as is

# Set the side length for the squares (adjust as needed)
square_side_length = 5

# Create squares around each point in the GeoDataFrame
power_plant_df['geometry'] = power_plant_df['geometry'].apply(
    lambda geometry: create_square_around_geometry(geometry, square_side_length)
)

# Display and plot the power plants GeoDataFrame with square polygons
display(power_plant_df)
ax = power_plant_df.plot()

# Reproject to EPSG 4326
bpolys = bpolys.to_crs(epsg=4326)
power_plant_df = power_plant_df.to_crs(epsg=4326)

# Save the plot to a file using fig.savefig()
fig = ax.get_figure()
fig.savefig("../plots/power_plants.png", dpi=300, bbox_inches="tight")

# Save the power plants GeoDataFrame with square polygons to a GeoJSON file
power_plant_df.to_file("../data/output/powerplants.geojson", driver='GeoJSON')
# Out:
# /Users/celinathome/anaconda3/lib/python3.11/site-packages/geopandas/geoseries.py:645: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   result = super().apply(func, convert_dtype=convert_dtype, args=args, **kwargs)
#                                                                                geometry  \
# @osmId           @snapshotTimestamp
# node/10235706898 2024-03-19 14:00:00  POLYGON ((438836.003 5294411.567, 438836.003 5...
# node/11432020075 2024-03-19 14:00:00  POLYGON ((474392.225 5472712.028, 474392.225 5...
# node/11523712555 2024-03-19 14:00:00  POLYGON ((513760.493 5409174.400, 513760.493 5...
# node/6481111957  2024-03-19 14:00:00  POLYGON ((407814.833 5277842.681, 407814.833 5...
# node/9481774146  2024-03-19 14:00:00  POLYGON ((595477.163 5428736.206, 595477.163 5...
# ...                                                                                 ...
# way/985575075    2024-03-19 14:00:00  POLYGON ((525732.633 5383089.773, 525751.882 5...
# way/986674594    2024-03-19 14:00:00  POLYGON ((483734.089 5296879.451, 483784.009 5...
# way/989243544    2024-03-19 14:00:00  POLYGON ((439145.397 5297231.243, 439167.042 5...
# way/989243545    2024-03-19 14:00:00  POLYGON ((439087.431 5297227.040, 439107.154 5...
# way/998316110    2024-03-19 14:00:00  POLYGON ((523251.842 5409170.494, 523250.321 5...
#
#                                       @changesetId             @lastEdit  \
# @osmId           @snapshotTimestamp
# node/10235706898 2024-03-19 14:00:00     129680029  2022-12-03T15:15:31Z
# node/11432020075 2024-03-19 14:00:00     145288627  2023-12-19T12:03:55Z
# node/11523712555 2024-03-19 14:00:00     146341698  2024-01-16T23:00:00Z
# node/6481111957  2024-03-19 14:00:00      70366736  2019-05-17T17:13:28Z
# node/9481774146  2024-03-19 14:00:00     143820221  2023-11-09T12:26:58Z
# ...                                            ...                   ...
# way/985575075    2024-03-19 14:00:00     126328232  2022-09-18T12:03:53Z
# way/986674594    2024-03-19 14:00:00     111649112  2021-09-24T13:50:42Z
# way/989243544    2024-03-19 14:00:00     127375345  2022-10-11T18:44:58Z
# way/989243545    2024-03-19 14:00:00     112051545  2021-10-03T23:19:37Z
# way/998316110    2024-03-19 14:00:00     138099665  2023-07-04T10:01:30Z
#
#                                      @osmType  @version  \
# @osmId           @snapshotTimestamp
# node/10235706898 2024-03-19 14:00:00     node         1
# node/11432020075 2024-03-19 14:00:00     node         1
# node/11523712555 2024-03-19 14:00:00     node         1
# node/6481111957  2024-03-19 14:00:00     node         3
# node/9481774146  2024-03-19 14:00:00     node         2
# ...                                       ...       ...
# way/985575075    2024-03-19 14:00:00      way         2
# way/986674594    2024-03-19 14:00:00      way         1
# way/989243544    2024-03-19 14:00:00      way         2
# way/989243545    2024-03-19 14:00:00      way         1
# way/998316110    2024-03-19 14:00:00      way         5
#
#                                                                   name  \
# @osmId           @snapshotTimestamp
# node/10235706898 2024-03-19 14:00:00  Wasserkraftwerk - Schaukraftwerk
# node/11432020075 2024-03-19 14:00:00                               NaN
# node/11523712555 2024-03-19 14:00:00                               NaN
# node/6481111957  2024-03-19 14:00:00       Wasserkraftwerk Maulburg II
# node/9481774146  2024-03-19 14:00:00                               NaN
# ...                                                                ...
# way/985575075    2024-03-19 14:00:00                               NaN
# way/986674594    2024-03-19 14:00:00                               NaN
# way/989243544    2024-03-19 14:00:00                               NaN
# way/989243545    2024-03-19 14:00:00                               NaN
# way/998316110    2024-03-19 14:00:00                               NaN
#
#                                            operator operator:wikidata  \
# @osmId           @snapshotTimestamp
# node/10235706898 2024-03-19 14:00:00            NaN               NaN
# node/11432020075 2024-03-19 14:00:00            NaN               NaN
# node/11523712555 2024-03-19 14:00:00            NaN               NaN
# node/6481111957  2024-03-19 14:00:00  Energiedienst               NaN
# node/9481774146  2024-03-19 14:00:00            NaN               NaN
# ...                                             ...               ...
# way/985575075    2024-03-19 14:00:00            NaN               NaN
# way/986674594    2024-03-19 14:00:00            NaN               NaN
# way/989243544    2024-03-19 14:00:00            NaN               NaN
# way/989243545    2024-03-19 14:00:00            NaN               NaN
# way/998316110    2024-03-19 14:00:00            NaN               NaN
#
#                                           plant:method  \
# @osmId           @snapshotTimestamp
# node/10235706898 2024-03-19 14:00:00               NaN
# node/11432020075 2024-03-19 14:00:00               NaN
# node/11523712555 2024-03-19 14:00:00      photovoltaic
# node/6481111957  2024-03-19 14:00:00  run-of-the-river
# node/9481774146  2024-03-19 14:00:00               NaN
# ...                                                ...
# way/985575075    2024-03-19 14:00:00      photovoltaic
# way/986674594    2024-03-19 14:00:00      photovoltaic
# way/989243544    2024-03-19 14:00:00           thermal
# way/989243545    2024-03-19 14:00:00      photovoltaic
# way/998316110    2024-03-19 14:00:00  run-of-the-river
#
#                                      plant:output:electricity  ... surface  \
# @osmId           @snapshotTimestamp                            ...
# node/10235706898 2024-03-19 14:00:00                      NaN  ...     NaN
# node/11432020075 2024-03-19 14:00:00                      NaN  ...     NaN
# node/11523712555 2024-03-19 14:00:00                      yes  ...     NaN
# node/6481111957  2024-03-19 14:00:00                   190 kW  ...     NaN
# node/9481774146  2024-03-19 14:00:00                      NaN  ...     NaN
# ...                                                       ...  ...     ...
# way/985575075    2024-03-19 14:00:00                      yes  ...     NaN
# way/986674594    2024-03-19 14:00:00                      NaN  ...     NaN
# way/989243544    2024-03-19 14:00:00                      NaN  ...     NaN
# way/989243545    2024-03-19 14:00:00                      NaN  ...     NaN
# way/998316110    2024-03-19 14:00:00                      yes  ...     NaN
#
#                                      ref:EEG fence_type building:min_level  \
# @osmId           @snapshotTimestamp
# node/10235706898 2024-03-19 14:00:00     NaN        NaN                NaN
# node/11432020075 2024-03-19 14:00:00     NaN        NaN                NaN
# node/11523712555 2024-03-19 14:00:00     NaN        NaN                NaN
# node/6481111957  2024-03-19 14:00:00     NaN        NaN                NaN
# node/9481774146  2024-03-19 14:00:00     NaN        NaN                NaN
# ...                                      ...        ...                ...
# way/985575075    2024-03-19 14:00:00     NaN        NaN                NaN
# way/986674594    2024-03-19 14:00:00     NaN        NaN                NaN
# way/989243544    2024-03-19 14:00:00     NaN      metal                NaN
# way/989243545    2024-03-19 14:00:00     NaN      metal                NaN
# way/998316110    2024-03-19 14:00:00     NaN        NaN                NaN
#
#                                      plant:output:gas  \
# @osmId           @snapshotTimestamp
# node/10235706898 2024-03-19 14:00:00              NaN
# node/11432020075 2024-03-19 14:00:00              NaN
# node/11523712555 2024-03-19 14:00:00              NaN
# node/6481111957  2024-03-19 14:00:00              NaN
# node/9481774146  2024-03-19 14:00:00              NaN
# ...                                               ...
# way/985575075    2024-03-19 14:00:00              NaN
# way/986674594    2024-03-19 14:00:00              NaN
# way/989243544    2024-03-19 14:00:00              NaN
# way/989243545    2024-03-19 14:00:00              NaN
# way/998316110    2024-03-19 14:00:00              NaN
#
#                                      source:plant:output:electricity  \
# @osmId           @snapshotTimestamp
# node/10235706898 2024-03-19 14:00:00                             NaN
# node/11432020075 2024-03-19 14:00:00                             NaN
# node/11523712555 2024-03-19 14:00:00                             NaN
# node/6481111957  2024-03-19 14:00:00                             NaN
# node/9481774146  2024-03-19 14:00:00                             NaN
# ...                                                              ...
# way/985575075    2024-03-19 14:00:00                             NaN
# way/986674594    2024-03-19 14:00:00                             NaN
# way/989243544    2024-03-19 14:00:00                             NaN
# way/989243545    2024-03-19 14:00:00                             NaN
# way/998316110    2024-03-19 14:00:00                             NaN
#
#                                      check_date addr:hamlet addr:housename  \
# @osmId           @snapshotTimestamp
# node/10235706898 2024-03-19 14:00:00        NaN         NaN            NaN
# node/11432020075 2024-03-19 14:00:00        NaN         NaN            NaN
# node/11523712555 2024-03-19 14:00:00        NaN         NaN            NaN
# node/6481111957  2024-03-19 14:00:00        NaN         NaN            NaN
# node/9481774146  2024-03-19 14:00:00        NaN         NaN            NaN
# ...                                         ...         ...            ...
# way/985575075    2024-03-19 14:00:00        NaN         NaN            NaN
# way/986674594    2024-03-19 14:00:00        NaN         NaN            NaN
# way/989243544    2024-03-19 14:00:00        NaN         NaN            NaN
# way/989243545    2024-03-19 14:00:00        NaN         NaN            NaN
# way/998316110    2024-03-19 14:00:00        NaN         NaN            NaN
#
#                                      plant:source:gas
# @osmId           @snapshotTimestamp
# node/10235706898 2024-03-19 14:00:00              NaN
# node/11432020075 2024-03-19 14:00:00              NaN
# node/11523712555 2024-03-19 14:00:00              NaN
# node/6481111957  2024-03-19 14:00:00              NaN
# node/9481774146  2024-03-19 14:00:00              NaN
# ...                                               ...
# way/985575075    2024-03-19 14:00:00              NaN
# way/986674594    2024-03-19 14:00:00              NaN
# way/989243544    2024-03-19 14:00:00              NaN
# way/989243545    2024-03-19 14:00:00              NaN
# way/998316110    2024-03-19 14:00:00              NaN
#
# [531 rows x 114 columns]

# %% [markdown]
# ## Download telecom data

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, box, GeometryCollection
from ohsome import OhsomeClient
import matplotlib.pyplot as plt

client = OhsomeClient()

# Load the geojson file with geopandas
bpolys = gpd.read_file("../data/input/baden_wuerttemberg.geojson")

# Define which OSM features should be considered for telecom
filter_telecom = "telecom=*"

# Make the request to ohsome API for telecom
response_telecom = client.elements.geometry.post(
    bpolys=bpolys,
    filter=filter_telecom,
    properties="tags,metadata"
)

# Convert the response to a GeoDataFrame for telecom
telecom_df = response_telecom.as_dataframe()

# Reproject to EPSG 25832 (ETRS89 / UTM Zone 32N)
bpolys = bpolys.to_crs(epsg=25832)
telecom_df = telecom_df.to_crs(epsg=25832)

# If you have Polygon geometries and you want to get the centroids, use the following:
telecom_df['geometry'] = telecom_df['geometry'].centroid

# Filter to include only Point geometries
telecom_points_df = telecom_df[telecom_df['geometry'].geom_type == 'Point']

# Display and plot the telecom points GeoDataFrame
display(telecom_points_df)
ax = telecom_points_df.plot()

# Reproject to EPSG 4326
bpolys = bpolys.to_crs(epsg=4326)
telecom_points_df = telecom_points_df.to_crs(epsg=4326)

# Save the plot to a file using fig.savefig()
fig = ax.get_figure()
fig.savefig("../plots/telecom_points.png", dpi=300, bbox_inches="tight")

# Save the telecom points GeoDataFrame to a GeoJSON file
telecom_points_df.to_file("../data/output/telecom_points.geojson", driver='GeoJSON')
# Out:
#                                                             geometry  \
# @osmId           @snapshotTimestamp
# node/10008693564 2024-03-19 14:00:00  POINT (421834.037 5370239.751)
# node/10008693565 2024-03-19 14:00:00  POINT (416994.906 5355946.141)
# node/10100762567 2024-03-19 14:00:00  POINT (416682.309 5355598.696)
# node/10219646042 2024-03-19 14:00:00  POINT (507749.741 5454241.607)
# node/10219705344 2024-03-19 14:00:00  POINT (508094.228 5454713.786)
# ...                                                              ...
# way/93578396     2024-03-19 14:00:00  POINT (401701.081 5276759.211)
# way/95171586     2024-03-19 14:00:00  POINT (535515.116 5464016.996)
# way/95847150     2024-03-19 14:00:00  POINT (477021.828 5390197.855)
# way/95847312     2024-03-19 14:00:00  POINT (477053.593 5390167.291)
# way/99217519     2024-03-19 14:00:00  POINT (510804.429 5281634.311)
#
#                                       @changesetId             @lastEdit  \
# @osmId           @snapshotTimestamp
# node/10008693564 2024-03-19 14:00:00     125938407  2022-09-08T11:19:49Z
# node/10008693565 2024-03-19 14:00:00     142464306  2023-10-12T07:12:43Z
# node/10100762567 2024-03-19 14:00:00     142464269  2023-10-12T07:11:26Z
# node/10219646042 2024-03-19 14:00:00     129401565  2022-11-26T13:06:51Z
# node/10219705344 2024-03-19 14:00:00     129402241  2022-11-26T13:27:27Z
# ...                                            ...                   ...
# way/93578396     2024-03-19 14:00:00      66065083  2019-01-06T09:19:27Z
# way/95171586     2024-03-19 14:00:00      68231622  2019-03-17T15:49:18Z
# way/95847150     2024-03-19 14:00:00     135349489  2023-04-25T15:38:43Z
# way/95847312     2024-03-19 14:00:00     135349489  2023-04-25T15:38:43Z
# way/99217519     2024-03-19 14:00:00     134748396  2023-04-10T20:36:04Z
#
#                                      @osmType  @version  addr:city  \
# @osmId           @snapshotTimestamp
# node/10008693564 2024-03-19 14:00:00     node         1        NaN
# node/10008693565 2024-03-19 14:00:00     node         2        NaN
# node/10100762567 2024-03-19 14:00:00     node         2        NaN
# node/10219646042 2024-03-19 14:00:00     node         1        NaN
# node/10219705344 2024-03-19 14:00:00     node         1        NaN
# ...                                       ...       ...        ...
# way/93578396     2024-03-19 14:00:00      way         2    Lörrach
# way/95171586     2024-03-19 14:00:00      way         4   Schöntal
# way/95847150     2024-03-19 14:00:00      way         3  Neubulach
# way/95847312     2024-03-19 14:00:00      way         2  Neubulach
# way/99217519     2024-03-19 14:00:00      way         9   Konstanz
#
#                                      addr:country addr:housenumber  \
# @osmId           @snapshotTimestamp
# node/10008693564 2024-03-19 14:00:00          NaN              NaN
# node/10008693565 2024-03-19 14:00:00          NaN              NaN
# node/10100762567 2024-03-19 14:00:00          NaN              NaN
# node/10219646042 2024-03-19 14:00:00          NaN              NaN
# node/10219705344 2024-03-19 14:00:00          NaN              NaN
# ...                                           ...              ...
# way/93578396     2024-03-19 14:00:00          NaN               30
# way/95171586     2024-03-19 14:00:00          NaN                5
# way/95847150     2024-03-19 14:00:00          NaN                9
# way/95847312     2024-03-19 14:00:00          NaN                3
# way/99217519     2024-03-19 14:00:00           DE                9
#
#                                      addr:postcode addr:street  ... level  \
# @osmId           @snapshotTimestamp                             ...
# node/10008693564 2024-03-19 14:00:00           NaN         NaN  ...   NaN
# node/10008693565 2024-03-19 14:00:00           NaN         NaN  ...   NaN
# node/10100762567 2024-03-19 14:00:00           NaN         NaN  ...   NaN
# node/10219646042 2024-03-19 14:00:00           NaN         NaN  ...   NaN
# node/10219705344 2024-03-19 14:00:00           NaN         NaN  ...   NaN
# ...                                            ...         ...  ...   ...
# way/93578396     2024-03-19 14:00:00         79541   Steinsack  ...   NaN
# way/95171586     2024-03-19 14:00:00         74214  Grüner Weg  ...   NaN
# way/95847150     2024-03-19 14:00:00         75387  Sperberweg  ...   NaN
# way/95847312     2024-03-19 14:00:00         75387  Sperberweg  ...   NaN
# way/99217519     2024-03-19 14:00:00         78467   Mühlenweg  ...   NaN
#
#                                      university addr:county addr:district  \
# @osmId           @snapshotTimestamp
# node/10008693564 2024-03-19 14:00:00        NaN         NaN           NaN
# node/10008693565 2024-03-19 14:00:00        NaN         NaN           NaN
# node/10100762567 2024-03-19 14:00:00        NaN         NaN           NaN
# node/10219646042 2024-03-19 14:00:00        NaN         NaN           NaN
# node/10219705344 2024-03-19 14:00:00        NaN         NaN           NaN
# ...                                         ...         ...           ...
# way/93578396     2024-03-19 14:00:00        NaN         NaN           NaN
# way/95171586     2024-03-19 14:00:00        NaN         NaN           NaN
# way/95847150     2024-03-19 14:00:00        NaN         NaN           NaN
# way/95847312     2024-03-19 14:00:00        NaN         NaN           NaN
# way/99217519     2024-03-19 14:00:00        NaN         NaN           NaN
#
#                                      addr:province man_made_1 addr:housename  \
# @osmId           @snapshotTimestamp
# node/10008693564 2024-03-19 14:00:00           NaN        NaN            NaN
# node/10008693565 2024-03-19 14:00:00           NaN        NaN            NaN
# node/10100762567 2024-03-19 14:00:00           NaN        NaN            NaN
# node/10219646042 2024-03-19 14:00:00           NaN        NaN            NaN
# node/10219705344 2024-03-19 14:00:00           NaN        NaN            NaN
# ...                                            ...        ...            ...
# way/93578396     2024-03-19 14:00:00           NaN        NaN            NaN
# way/95171586     2024-03-19 14:00:00           NaN        NaN            NaN
# way/95847150     2024-03-19 14:00:00           NaN        NaN            NaN
# way/95847312     2024-03-19 14:00:00           NaN        NaN            NaN
# way/99217519     2024-03-19 14:00:00           NaN        NaN            NaN
#
#                                      start_date:note check_date  \
# @osmId           @snapshotTimestamp
# node/10008693564 2024-03-19 14:00:00             NaN        NaN
# node/10008693565 2024-03-19 14:00:00             NaN        NaN
# node/10100762567 2024-03-19 14:00:00             NaN        NaN
# node/10219646042 2024-03-19 14:00:00             NaN        NaN
# node/10219705344 2024-03-19 14:00:00             NaN        NaN
# ...                                              ...        ...
# way/93578396     2024-03-19 14:00:00             NaN        NaN
# way/95171586     2024-03-19 14:00:00             NaN        NaN
# way/95847150     2024-03-19 14:00:00             NaN        NaN
# way/95847312     2024-03-19 14:00:00             NaN        NaN
# way/99217519     2024-03-19 14:00:00             NaN        NaN
#
#                                      contact:country
# @osmId           @snapshotTimestamp
# node/10008693564 2024-03-19 14:00:00             NaN
# node/10008693565 2024-03-19 14:00:00             NaN
# node/10100762567 2024-03-19 14:00:00             NaN
# node/10219646042 2024-03-19 14:00:00             NaN
# node/10219705344 2024-03-19 14:00:00             NaN
# ...                                              ...
# way/93578396     2024-03-19 14:00:00             NaN
# way/95171586     2024-03-19 14:00:00             NaN
# way/95847150     2024-03-19 14:00:00             NaN
# way/95847312     2024-03-19 14:00:00             NaN
# way/99217519     2024-03-19 14:00:00             NaN
#
# [1107 rows x 104 columns]

# %% [markdown]
# ## Download water

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, box, GeometryCollection
from ohsome import OhsomeClient

client = OhsomeClient()

# Load the geojson file with geopandas
bpolys = gpd.read_file("../data/input/baden_wuerttemberg.geojson")

# Define which OSM features should be considered for water
filter_water = "water=*"

# Make the request to ohsome API for water
response_water = client.elements.geometry.post(
    bpolys=bpolys,
    filter=filter_water,
    properties="tags,metadata"
)

# Convert the response to a GeoDataFrame for water
water_df = response_water.as_dataframe()

# Display and plot water GeoDataFrame
display(water_df)
ax = water_df.plot()

# Save the plot to a file using fig.savefig()
fig = ax.get_figure()
fig.savefig("../plots/water.png", dpi=300, bbox_inches="tight")

# Save the water GeoDataFrame to a GeoJSON file
water_df.to_file("../data/output/water.geojson", driver='GeoJSON')
# Out:
#                                                                                geometry  \
# @osmId           @snapshotTimestamp
# node/10083343529 2024-03-19 14:00:00                           POINT (9.24313 48.78569)
# node/11015645409 2024-03-19 14:00:00                           POINT (8.68713 48.15156)
# node/11035825400 2024-03-19 14:00:00                           POINT (7.64224 47.88087)
# node/1113685994  2024-03-19 14:00:00                           POINT (9.33843 48.43883)
# node/11346665007 2024-03-19 14:00:00                           POINT (9.80222 48.85180)
# ...                                                                                 ...
# way/999972880    2024-03-19 14:00:00  POLYGON ((8.67539 49.35181, 8.67562 49.35182, ...
# way/999982237    2024-03-19 14:00:00  POLYGON ((9.02466 48.42226, 9.02445 48.42205, ...
# way/999989477    2024-03-19 14:00:00  POLYGON ((10.40789 48.91153, 10.40788 48.91158...
# way/999991940    2024-03-19 14:00:00  POLYGON ((10.39840 48.92122, 10.39840 48.92128...
# way/999991941    2024-03-19 14:00:00  POLYGON ((10.39840 48.92107, 10.39841 48.92114...
#
#                                       @changesetId             @lastEdit  \
# @osmId           @snapshotTimestamp
# node/10083343529 2024-03-19 14:00:00     127190685  2022-10-08T09:33:32Z
# node/11015645409 2024-03-19 14:00:00     137950925  2023-06-30T09:50:47Z
# node/11035825400 2024-03-19 14:00:00     138304303  2023-07-09T17:05:08Z
# node/1113685994  2024-03-19 14:00:00      12079993  2012-07-01T19:14:21Z
# node/11346665007 2024-03-19 14:00:00     143976579  2023-11-13T15:53:08Z
# ...                                            ...                   ...
# way/999972880    2024-03-19 14:00:00     113452618  2021-11-06T16:11:51Z
# way/999982237    2024-03-19 14:00:00     113453905  2021-11-06T16:42:16Z
# way/999989477    2024-03-19 14:00:00     113455548  2021-11-06T17:22:20Z
# way/999991940    2024-03-19 14:00:00     123462685  2022-07-11T08:37:35Z
# way/999991941    2024-03-19 14:00:00     123462685  2022-07-11T08:37:35Z
#
#                                      @osmType  @version intermittent  \
# @osmId           @snapshotTimestamp
# node/10083343529 2024-03-19 14:00:00     node         1          NaN
# node/11015645409 2024-03-19 14:00:00     node         1          NaN
# node/11035825400 2024-03-19 14:00:00     node         1          NaN
# node/1113685994  2024-03-19 14:00:00     node         3          NaN
# node/11346665007 2024-03-19 14:00:00     node         1          NaN
# ...                                       ...       ...          ...
# way/999972880    2024-03-19 14:00:00      way         1          yes
# way/999982237    2024-03-19 14:00:00      way         1          yes
# way/999989477    2024-03-19 14:00:00      way         1          NaN
# way/999991940    2024-03-19 14:00:00      way         2          NaN
# way/999991941    2024-03-19 14:00:00      way         2          NaN
#
#                                                name natural salt      water  \
# @osmId           @snapshotTimestamp
# node/10083343529 2024-03-19 14:00:00            NaN     NaN  NaN       main
# node/11015645409 2024-03-19 14:00:00            NaN     NaN  NaN       pond
# node/11035825400 2024-03-19 14:00:00            LWB   water  NaN  reservoir
# node/1113685994  2024-03-19 14:00:00   Erndtbrunnen  spring  NaN     source
# node/11346665007 2024-03-19 14:00:00  Hummelsgraben   water  NaN      ditch
# ...                                             ...     ...  ...        ...
# way/999972880    2024-03-19 14:00:00            NaN   water  NaN      basin
# way/999982237    2024-03-19 14:00:00            NaN   water  NaN      basin
# way/999989477    2024-03-19 14:00:00            NaN   water  NaN       pond
# way/999991940    2024-03-19 14:00:00            NaN   water  NaN  reservoir
# way/999991941    2024-03-19 14:00:00            NaN   water  NaN  reservoir
#
#                                       ... swimming_pool hazard:de blind  \
# @osmId           @snapshotTimestamp   ...
# node/10083343529 2024-03-19 14:00:00  ...           NaN       NaN   NaN
# node/11015645409 2024-03-19 14:00:00  ...           NaN       NaN   NaN
# node/11035825400 2024-03-19 14:00:00  ...           NaN       NaN   NaN
# node/1113685994  2024-03-19 14:00:00  ...           NaN       NaN   NaN
# node/11346665007 2024-03-19 14:00:00  ...           NaN       NaN   NaN
# ...                                   ...           ...       ...   ...
# way/999972880    2024-03-19 14:00:00  ...           NaN       NaN   NaN
# way/999982237    2024-03-19 14:00:00  ...           NaN       NaN   NaN
# way/999989477    2024-03-19 14:00:00  ...           NaN       NaN   NaN
# way/999991940    2024-03-19 14:00:00  ...           NaN       NaN   NaN
# way/999991941    2024-03-19 14:00:00  ...           NaN       NaN   NaN
#
#                                      playground:theme date denotation fence  \
# @osmId           @snapshotTimestamp
# node/10083343529 2024-03-19 14:00:00              NaN  NaN        NaN   NaN
# node/11015645409 2024-03-19 14:00:00              NaN  NaN        NaN   NaN
# node/11035825400 2024-03-19 14:00:00              NaN  NaN        NaN   NaN
# node/1113685994  2024-03-19 14:00:00              NaN  NaN        NaN   NaN
# node/11346665007 2024-03-19 14:00:00              NaN  NaN        NaN   NaN
# ...                                               ...  ...        ...   ...
# way/999972880    2024-03-19 14:00:00              NaN  NaN        NaN   NaN
# way/999982237    2024-03-19 14:00:00              NaN  NaN        NaN   NaN
# way/999989477    2024-03-19 14:00:00              NaN  NaN        NaN   NaN
# way/999991940    2024-03-19 14:00:00              NaN  NaN        NaN   NaN
# way/999991941    2024-03-19 14:00:00              NaN  NaN        NaN   NaN
#
#                                      end_date note:geometry supervised
# @osmId           @snapshotTimestamp
# node/10083343529 2024-03-19 14:00:00      NaN           NaN        NaN
# node/11015645409 2024-03-19 14:00:00      NaN           NaN        NaN
# node/11035825400 2024-03-19 14:00:00      NaN           NaN        NaN
# node/1113685994  2024-03-19 14:00:00      NaN           NaN        NaN
# node/11346665007 2024-03-19 14:00:00      NaN           NaN        NaN
# ...                                       ...           ...        ...
# way/999972880    2024-03-19 14:00:00      NaN           NaN        NaN
# way/999982237    2024-03-19 14:00:00      NaN           NaN        NaN
# way/999989477    2024-03-19 14:00:00      NaN           NaN        NaN
# way/999991940    2024-03-19 14:00:00      NaN           NaN        NaN
# way/999991941    2024-03-19 14:00:00      NaN           NaN        NaN
#
# [14764 rows x 219 columns]

# %% [markdown]
# ## Download settlements

# %% [markdown]
# ### Download all admin levels

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, box, GeometryCollection
from ohsome import OhsomeClient

client = OhsomeClient()

# Load the geojson file with geopandas
bpolys = gpd.read_file("../data/input/baden_wuerttemberg.geojson")

# Define which OSM features should be considered for administrative boundaries
filter_admin = "admin_level=*"

# Make the request to ohsome API for administrative boundaries
response_admin = client.elements.geometry.post(
    bpolys=bpolys,
    filter=filter_admin,
    properties="tags,metadata"
)

# Convert the response to a GeoDataFrame for administrative boundaries
admin_df = response_admin.as_dataframe()

# Ensure that the 'geometry' column contains polygon geometries
admin_df = admin_df[admin_df['geometry'].geom_type == 'Polygon']

# Display and plot administrative boundaries GeoDataFrame
display(admin_df)
admin_df.plot()

# Save the administrative boundaries GeoDataFrame to a GeoJSON file
admin_df.to_file("../data/output/administrative_boundaries_all.geojson", driver='GeoJSON')
# Out:
#                                                                                 geometry  \
# @osmId            @snapshotTimestamp
# relation/10180634 2024-03-19 14:00:00  POLYGON ((7.82338 48.61184, 7.82503 48.61371, ...
# relation/10180638 2024-03-19 14:00:00  POLYGON ((7.83202 48.62274, 7.83303 48.62488, ...
# relation/10253405 2024-03-19 14:00:00  POLYGON ((8.26149 48.98099, 8.26149 48.98099, ...
# relation/10253406 2024-03-19 14:00:00  POLYGON ((8.35451 48.93455, 8.35403 48.93470, ...
# relation/10253407 2024-03-19 14:00:00  POLYGON ((8.33201 48.98873, 8.33269 48.98836, ...
# ...                                                                                  ...
# way/737048810     2024-03-19 14:00:00  POLYGON ((7.87524 48.60612, 7.87718 48.60924, ...
# way/73845577      2024-03-19 14:00:00  POLYGON ((8.19234 48.74580, 8.19330 48.74492, ...
# way/82672837      2024-03-19 14:00:00  POLYGON ((8.93736 47.89451, 8.93755 47.89456, ...
# way/957918843     2024-03-19 14:00:00  POLYGON ((9.13456 48.95459, 9.13517 48.95455, ...
# way/9712941       2024-03-19 14:00:00  POLYGON ((9.18298 48.77849, 9.18299 48.77849, ...
#
#                                        @changesetId             @lastEdit  \
# @osmId            @snapshotTimestamp
# relation/10180634 2024-03-19 14:00:00      75956892  2019-10-20T15:15:04Z
# relation/10180638 2024-03-19 14:00:00     100610678  2021-03-08T06:41:06Z
# relation/10253405 2024-03-19 14:00:00      76549652  2019-11-03T12:19:19Z
# relation/10253406 2024-03-19 14:00:00     107229556  2021-06-30T21:35:41Z
# relation/10253407 2024-03-19 14:00:00     107229556  2021-06-30T21:35:38Z
# ...                                             ...                   ...
# way/737048810     2024-03-19 14:00:00      75956892  2019-10-20T15:15:04Z
# way/73845577      2024-03-19 14:00:00      17544110  2013-08-27T20:27:16Z
# way/82672837      2024-03-19 14:00:00      61534788  2018-08-10T12:28:46Z
# way/957918843     2024-03-19 14:00:00     135692415  2023-05-04T09:35:03Z
# way/9712941       2024-03-19 14:00:00     141362683  2023-09-17T00:25:33Z
#
#                                        @osmType  @version admin_level  \
# @osmId            @snapshotTimestamp
# relation/10180634 2024-03-19 14:00:00  relation         1           9
# relation/10180638 2024-03-19 14:00:00  relation         2           9
# relation/10253405 2024-03-19 14:00:00  relation         1          10
# relation/10253406 2024-03-19 14:00:00  relation         2          10
# relation/10253407 2024-03-19 14:00:00  relation         2          10
# ...                                         ...       ...         ...
# way/737048810     2024-03-19 14:00:00       way         1           9
# way/73845577      2024-03-19 14:00:00       way         3           6
# way/82672837      2024-03-19 14:00:00       way         3           8
# way/957918843     2024-03-19 14:00:00       way         2          11
# way/9712941       2024-03-19 14:00:00       way        21           4
#
#                                              boundary  \
# @osmId            @snapshotTimestamp
# relation/10180634 2024-03-19 14:00:00  administrative
# relation/10180638 2024-03-19 14:00:00  administrative
# relation/10253405 2024-03-19 14:00:00  administrative
# relation/10253406 2024-03-19 14:00:00  administrative
# relation/10253407 2024-03-19 14:00:00  administrative
# ...                                               ...
# way/737048810     2024-03-19 14:00:00  administrative
# way/73845577      2024-03-19 14:00:00  administrative
# way/82672837      2024-03-19 14:00:00  administrative
# way/957918843     2024-03-19 14:00:00  administrative
# way/9712941       2024-03-19 14:00:00             NaN
#
#                                                                                   source  \
# @osmId            @snapshotTimestamp
# relation/10180634 2024-03-19 14:00:00                                                NaN
# relation/10180638 2024-03-19 14:00:00                                                NaN
# relation/10253405 2024-03-19 14:00:00                                                NaN
# relation/10253406 2024-03-19 14:00:00                                                NaN
# relation/10253407 2024-03-19 14:00:00                                                NaN
# ...                                                                                  ...
# way/737048810     2024-03-19 14:00:00                                                NaN
# way/73845577      2024-03-19 14:00:00                                                NaN
# way/82672837      2024-03-19 14:00:00  http://de.wikipedia.org/wiki/Datei:Municipalit...
# way/957918843     2024-03-19 14:00:00                                                NaN
# way/9712941       2024-03-19 14:00:00                                                NaN
#
#                                                     name      office  ...  \
# @osmId            @snapshotTimestamp                                  ...
# relation/10180634 2024-03-19 14:00:00           Auenheim         NaN  ...
# relation/10180638 2024-03-19 14:00:00         Leutesheim         NaN  ...
# relation/10253405 2024-03-19 14:00:00       Neuburgweier         NaN  ...
# relation/10253406 2024-03-19 14:00:00             Mörsch         NaN  ...
# relation/10253407 2024-03-19 14:00:00          Forchheim         NaN  ...
# ...                                                  ...         ...  ...
# way/737048810     2024-03-19 14:00:00                NaN         NaN  ...
# way/73845577      2024-03-19 14:00:00                NaN         NaN  ...
# way/82672837      2024-03-19 14:00:00                NaN         NaN  ...
# way/957918843     2024-03-19 14:00:00                NaN         NaN  ...
# way/9712941       2024-03-19 14:00:00  Haus des Landtags  government  ...
#
#                                       old_name:ru alt_name:mk coat_of_arms  \
# @osmId            @snapshotTimestamp
# relation/10180634 2024-03-19 14:00:00         NaN         NaN          NaN
# relation/10180638 2024-03-19 14:00:00         NaN         NaN          NaN
# relation/10253405 2024-03-19 14:00:00         NaN         NaN          NaN
# relation/10253406 2024-03-19 14:00:00         NaN         NaN          NaN
# relation/10253407 2024-03-19 14:00:00         NaN         NaN          NaN
# ...                                           ...         ...          ...
# way/737048810     2024-03-19 14:00:00         NaN         NaN          NaN
# way/73845577      2024-03-19 14:00:00         NaN         NaN          NaN
# way/82672837      2024-03-19 14:00:00         NaN         NaN          NaN
# way/957918843     2024-03-19 14:00:00         NaN         NaN          NaN
# way/9712941       2024-03-19 14:00:00         NaN         NaN          NaN
#
#                                       is_in:country_code alt_name:gsw  \
# @osmId            @snapshotTimestamp
# relation/10180634 2024-03-19 14:00:00                NaN          NaN
# relation/10180638 2024-03-19 14:00:00                NaN          NaN
# relation/10253405 2024-03-19 14:00:00                NaN          NaN
# relation/10253406 2024-03-19 14:00:00                NaN          NaN
# relation/10253407 2024-03-19 14:00:00                NaN          NaN
# ...                                                  ...          ...
# way/737048810     2024-03-19 14:00:00                NaN          NaN
# way/73845577      2024-03-19 14:00:00                NaN          NaN
# way/82672837      2024-03-19 14:00:00                NaN          NaN
# way/957918843     2024-03-19 14:00:00                NaN          NaN
# way/9712941       2024-03-19 14:00:00                NaN          NaN
#
#                                       capital_city country_code_fips  \
# @osmId            @snapshotTimestamp
# relation/10180634 2024-03-19 14:00:00          NaN               NaN
# relation/10180638 2024-03-19 14:00:00          NaN               NaN
# relation/10253405 2024-03-19 14:00:00          NaN               NaN
# relation/10253406 2024-03-19 14:00:00          NaN               NaN
# relation/10253407 2024-03-19 14:00:00          NaN               NaN
# ...                                            ...               ...
# way/737048810     2024-03-19 14:00:00          NaN               NaN
# way/73845577      2024-03-19 14:00:00          NaN               NaN
# way/82672837      2024-03-19 14:00:00          NaN               NaN
# way/957918843     2024-03-19 14:00:00          NaN               NaN
# way/9712941       2024-03-19 14:00:00          NaN               NaN
#
#                                       official_name:la official_name:rm  \
# @osmId            @snapshotTimestamp
# relation/10180634 2024-03-19 14:00:00              NaN              NaN
# relation/10180638 2024-03-19 14:00:00              NaN              NaN
# relation/10253405 2024-03-19 14:00:00              NaN              NaN
# relation/10253406 2024-03-19 14:00:00              NaN              NaN
# relation/10253407 2024-03-19 14:00:00              NaN              NaN
# ...                                                ...              ...
# way/737048810     2024-03-19 14:00:00              NaN              NaN
# way/73845577      2024-03-19 14:00:00              NaN              NaN
# way/82672837      2024-03-19 14:00:00              NaN              NaN
# way/957918843     2024-03-19 14:00:00              NaN              NaN
# way/9712941       2024-03-19 14:00:00              NaN              NaN
#
#                                       old_name:cs
# @osmId            @snapshotTimestamp
# relation/10180634 2024-03-19 14:00:00         NaN
# relation/10180638 2024-03-19 14:00:00         NaN
# relation/10253405 2024-03-19 14:00:00         NaN
# relation/10253406 2024-03-19 14:00:00         NaN
# relation/10253407 2024-03-19 14:00:00         NaN
# ...                                           ...
# way/737048810     2024-03-19 14:00:00         NaN
# way/73845577      2024-03-19 14:00:00         NaN
# way/82672837      2024-03-19 14:00:00         NaN
# way/957918843     2024-03-19 14:00:00         NaN
# way/9712941       2024-03-19 14:00:00         NaN
#
# [2574 rows x 618 columns]

# %% [markdown]
# ## Download nature reserves

# %%
import pandas as pd
import geopandas as gpd
from ohsome import OhsomeClient

client = OhsomeClient()

# Load the geojson file with geopandas
bpolys = gpd.read_file("../data/input/baden_wuerttemberg.geojson")

# Define which OSM features should be considered for nature reserves.
filter_nature_reserve = "leisure=nature_reserve"

# Make the request to ohsome API for nature reserve
response_nature_reserve = client.elements.geometry.post(
    bpolys=bpolys,
    filter=filter_nature_reserve,
    properties="tags,metadata"
)

# Filter the response to include only polygons
nature_reserve_df = response_nature_reserve.as_dataframe()
nature_reserve_df = nature_reserve_df[nature_reserve_df.geometry.type == 'Polygon']

# Display and plot the nature reserves GeoDataFrame
display(nature_reserve_df)
nature_reserve_df.plot()

# Save the nature reserves GeoDataFrame to a GeoJSON file
nature_reserve_df.to_file("../data/output/nature_reserve.geojson", driver='GeoJSON')
# Out:
#                                                                                 geometry  \
# @osmId            @snapshotTimestamp
# relation/11199841 2024-03-19 14:00:00  POLYGON ((9.76263 47.83266, 9.76318 47.83266, ...
# relation/11292623 2024-03-19 14:00:00  POLYGON ((8.93973 49.30538, 8.94003 49.30532, ...
# relation/11294696 2024-03-19 14:00:00  POLYGON ((8.78790 49.38151, 8.78833 49.38203, ...
# relation/11304365 2024-03-19 14:00:00  POLYGON ((8.61350 49.13005, 8.61438 49.13016, ...
# relation/11316227 2024-03-19 14:00:00  POLYGON ((8.48720 48.84637, 8.48778 48.84651, ...
# ...                                                                                  ...
# way/972037681     2024-03-19 14:00:00  POLYGON ((7.63015 48.07343, 7.63200 48.07243, ...
# way/972042527     2024-03-19 14:00:00  POLYGON ((7.64246 48.07347, 7.64230 48.07342, ...
# way/972048896     2024-03-19 14:00:00  POLYGON ((7.77759 48.23348, 7.77764 48.23355, ...
# way/972051192     2024-03-19 14:00:00  POLYGON ((8.19281 48.56618, 8.19334 48.56595, ...
# way/98388087      2024-03-19 14:00:00  POLYGON ((8.84233 48.80440, 8.84226 48.80473, ...
#
#                                        @changesetId             @lastEdit  \
# @osmId            @snapshotTimestamp
# relation/11199841 2024-03-19 14:00:00      86597507  2020-06-13T11:52:30Z
# relation/11292623 2024-03-19 14:00:00      87852793  2020-07-11T13:46:24Z
# relation/11294696 2024-03-19 14:00:00      87871702  2020-07-12T10:00:39Z
# relation/11304365 2024-03-19 14:00:00      87994236  2020-07-14T20:25:15Z
# relation/11316227 2024-03-19 14:00:00      88203914  2020-07-19T15:35:32Z
# ...                                             ...                   ...
# way/972037681     2024-03-19 14:00:00     137532582  2023-06-19T19:26:45Z
# way/972042527     2024-03-19 14:00:00     137532582  2023-06-19T19:26:45Z
# way/972048896     2024-03-19 14:00:00     137532582  2023-06-19T19:26:45Z
# way/972051192     2024-03-19 14:00:00     137532582  2023-06-19T19:26:45Z
# way/98388087      2024-03-19 14:00:00      88421491  2020-07-23T19:19:05Z
#
#                                        @osmType  @version         leisure  \
# @osmId            @snapshotTimestamp
# relation/11199841 2024-03-19 14:00:00  relation         1  nature_reserve
# relation/11292623 2024-03-19 14:00:00  relation         1  nature_reserve
# relation/11294696 2024-03-19 14:00:00  relation         1  nature_reserve
# relation/11304365 2024-03-19 14:00:00  relation         1  nature_reserve
# relation/11316227 2024-03-19 14:00:00  relation         2  nature_reserve
# ...                                         ...       ...             ...
# way/972037681     2024-03-19 14:00:00       way         2  nature_reserve
# way/972042527     2024-03-19 14:00:00       way         3  nature_reserve
# way/972048896     2024-03-19 14:00:00       way         3  nature_reserve
# way/972051192     2024-03-19 14:00:00       way         2  nature_reserve
# way/98388087      2024-03-19 14:00:00       way         3  nature_reserve
#
#                                                                   name  \
# @osmId            @snapshotTimestamp
# relation/11199841 2024-03-19 14:00:00                              NaN
# relation/11292623 2024-03-19 14:00:00       Waibstädter Schwarzbachaue
# relation/11294696 2024-03-19 14:00:00            Elsenzaue-Hollmuthang
# relation/11304365 2024-03-19 14:00:00                        Rotenberg
# relation/11316227 2024-03-19 14:00:00                     Pfinzquellen
# ...                                                                ...
# way/972037681     2024-03-19 14:00:00                    Schneckenberg
# way/972042527     2024-03-19 14:00:00                       Bitzenberg
# way/972048896     2024-03-19 14:00:00          Steinbruch Ehrleshalden
# way/972051192     2024-03-19 14:00:00  Gottschlägtal - Karlsruher Grat
# way/98388087      2024-03-19 14:00:00                       Silberberg
#
#                                       natural_protection   wikidata leaf_type  \
# @osmId            @snapshotTimestamp
# relation/11199841 2024-03-19 14:00:00                NaN        NaN       NaN
# relation/11292623 2024-03-19 14:00:00                NaN  Q62026808       NaN
# relation/11294696 2024-03-19 14:00:00                NaN  Q62026875       NaN
# relation/11304365 2024-03-19 14:00:00                NaN  Q62026890       NaN
# relation/11316227 2024-03-19 14:00:00                NaN  Q57814657       NaN
# ...                                                  ...        ...       ...
# way/972037681     2024-03-19 14:00:00                NaN        NaN       NaN
# way/972042527     2024-03-19 14:00:00                NaN  Q62026943       NaN
# way/972048896     2024-03-19 14:00:00                NaN  Q15130332       NaN
# way/972051192     2024-03-19 14:00:00                NaN  Q21957438       NaN
# way/98388087      2024-03-19 14:00:00                NaN  Q50325118       NaN
#
#                                        ... camping dtp_id horse motor_vehicle  \
# @osmId            @snapshotTimestamp   ...
# relation/11199841 2024-03-19 14:00:00  ...     NaN    NaN   NaN           NaN
# relation/11292623 2024-03-19 14:00:00  ...     NaN    NaN   NaN           NaN
# relation/11294696 2024-03-19 14:00:00  ...     NaN    NaN   NaN           NaN
# relation/11304365 2024-03-19 14:00:00  ...     NaN    NaN   NaN           NaN
# relation/11316227 2024-03-19 14:00:00  ...     NaN    NaN   NaN           NaN
# ...                                    ...     ...    ...   ...           ...
# way/972037681     2024-03-19 14:00:00  ...     NaN    NaN   NaN           NaN
# way/972042527     2024-03-19 14:00:00  ...     NaN    NaN   NaN           NaN
# way/972048896     2024-03-19 14:00:00  ...     NaN    NaN   NaN           NaN
# way/972051192     2024-03-19 14:00:00  ...     NaN    NaN   NaN           NaN
# way/98388087      2024-03-19 14:00:00  ...     NaN    NaN   NaN           NaN
#
#                                       openfire addr:city abandoned:landuse  \
# @osmId            @snapshotTimestamp
# relation/11199841 2024-03-19 14:00:00      NaN       NaN               NaN
# relation/11292623 2024-03-19 14:00:00      NaN       NaN               NaN
# relation/11294696 2024-03-19 14:00:00      NaN       NaN               NaN
# relation/11304365 2024-03-19 14:00:00      NaN       NaN               NaN
# relation/11316227 2024-03-19 14:00:00      NaN       NaN               NaN
# ...                                        ...       ...               ...
# way/972037681     2024-03-19 14:00:00      NaN       NaN               NaN
# way/972042527     2024-03-19 14:00:00      NaN       NaN               NaN
# way/972048896     2024-03-19 14:00:00      NaN       NaN               NaN
# way/972051192     2024-03-19 14:00:00      NaN       NaN               NaN
# way/98388087      2024-03-19 14:00:00      NaN       NaN               NaN
#
#                                       survey:date noname protection_aim
# @osmId            @snapshotTimestamp
# relation/11199841 2024-03-19 14:00:00         NaN    NaN            NaN
# relation/11292623 2024-03-19 14:00:00         NaN    NaN            NaN
# relation/11294696 2024-03-19 14:00:00         NaN    NaN            NaN
# relation/11304365 2024-03-19 14:00:00         NaN    NaN            NaN
# relation/11316227 2024-03-19 14:00:00         NaN    NaN            NaN
# ...                                           ...    ...            ...
# way/972037681     2024-03-19 14:00:00         NaN    NaN            NaN
# way/972042527     2024-03-19 14:00:00         NaN    NaN            NaN
# way/972048896     2024-03-19 14:00:00         NaN    NaN            NaN
# way/972051192     2024-03-19 14:00:00         NaN    NaN            NaN
# way/98388087      2024-03-19 14:00:00         NaN    NaN            NaN
#
# [608 rows x 101 columns]

# %% [markdown]
# ## Download protected areas

# %%
import pandas as pd
import geopandas as gpd
from ohsome import OhsomeClient

client = OhsomeClient()

# Load the GeoJSON file with geopandas
bpolys = gpd.read_file("../data/input/baden_wuerttemberg.geojson")

# Define which OSM features should be considered for protected areas
filter_protected_area = "boundary=protected_area"

# Make the request to ohsome API for nature reserve
response_protected_area = client.elements.geometry.post(
    bpolys=bpolys,
    filter=filter_protected_area,
    properties="tags,metadata"
)

# Convert the response to a GeoDataFrame for protected areas
protected_area_df = response_protected_area.as_dataframe()

# Filter the GeoDataFrame to include only polygons and multi-polygons
filtered_protected_area_df = protected_area_df[protected_area_df.geom_type.isin(['Polygon', 'MultiPolygon'])]

# Display the filtered protected area GeoDataFrame
display(filtered_protected_area_df)

# Plot the protected area GeoDataFrame
filtered_protected_area_df.plot()

# Save the filtered protected areas GeoDataFrame to a GeoJSON file
filtered_protected_area_df.to_file("../data/output/protected_area.geojson", driver='GeoJSON')
# Out:
#                                                                                 geometry  \
# @osmId            @snapshotTimestamp
# relation/10116799 2024-03-19 14:00:00  MULTIPOLYGON (((7.99000 48.73688, 7.99026 48.7...
# relation/10168615 2024-03-19 14:00:00  MULTIPOLYGON (((8.42287 48.70140, 8.42238 48.7...
# relation/10830286 2024-03-19 14:00:00  MULTIPOLYGON (((9.34398 47.73197, 9.34394 47.7...
# relation/11267834 2024-03-19 14:00:00  MULTIPOLYGON (((9.28212 48.79181, 9.28279 48.7...
# relation/11283442 2024-03-19 14:00:00  MULTIPOLYGON (((8.61294 48.92813, 8.61393 48.9...
# ...                                                                                  ...
# way/9955306       2024-03-19 14:00:00  POLYGON ((8.53546 49.31616, 8.53519 49.31620, ...
# way/99578434      2024-03-19 14:00:00  POLYGON ((8.08253 48.70506, 8.08467 48.70452, ...
# way/99578437      2024-03-19 14:00:00  POLYGON ((8.07965 48.70440, 8.08061 48.70365, ...
# way/998244502     2024-03-19 14:00:00  POLYGON ((9.49387 48.93094, 9.49405 48.93091, ...
# way/998244503     2024-03-19 14:00:00  POLYGON ((9.49297 48.93043, 9.49338 48.93035, ...
#
#                                        @changesetId             @lastEdit  \
# @osmId            @snapshotTimestamp
# relation/10116799 2024-03-19 14:00:00     137532582  2023-06-19T19:26:45Z
# relation/10168615 2024-03-19 14:00:00     137532582  2023-06-19T19:26:45Z
# relation/10830286 2024-03-19 14:00:00      89415220  2020-08-14T13:56:40Z
# relation/11267834 2024-03-19 14:00:00     141343189  2023-09-16T13:35:08Z
# relation/11283442 2024-03-19 14:00:00      88263808  2020-07-20T20:19:23Z
# ...                                             ...                   ...
# way/9955306       2024-03-19 14:00:00     103973058  2021-05-01T20:26:36Z
# way/99578434      2024-03-19 14:00:00     141360810  2023-09-16T22:34:25Z
# way/99578437      2024-03-19 14:00:00     141360810  2023-09-16T22:34:25Z
# way/998244502     2024-03-19 14:00:00     131688215  2023-01-25T10:21:03Z
# way/998244503     2024-03-19 14:00:00     113255299  2021-11-01T21:08:53Z
#
#                                        @osmType  @version        boundary  \
# @osmId            @snapshotTimestamp
# relation/10116799 2024-03-19 14:00:00  relation         4  protected_area
# relation/10168615 2024-03-19 14:00:00  relation         8  protected_area
# relation/10830286 2024-03-19 14:00:00  relation         4  protected_area
# relation/11267834 2024-03-19 14:00:00  relation         8  protected_area
# relation/11283442 2024-03-19 14:00:00  relation         3  protected_area
# ...                                         ...       ...             ...
# way/9955306       2024-03-19 14:00:00       way        11  protected_area
# way/99578434      2024-03-19 14:00:00       way         3  protected_area
# way/99578437      2024-03-19 14:00:00       way         5  protected_area
# way/998244502     2024-03-19 14:00:00       way         6  protected_area
# way/998244503     2024-03-19 14:00:00       way         1  protected_area
#
#                                               leisure  \
# @osmId            @snapshotTimestamp
# relation/10116799 2024-03-19 14:00:00  nature_reserve
# relation/10168615 2024-03-19 14:00:00  nature_reserve
# relation/10830286 2024-03-19 14:00:00             NaN
# relation/11267834 2024-03-19 14:00:00             NaN
# relation/11283442 2024-03-19 14:00:00  nature_reserve
# ...                                               ...
# way/9955306       2024-03-19 14:00:00             NaN
# way/99578434      2024-03-19 14:00:00             NaN
# way/99578437      2024-03-19 14:00:00             NaN
# way/998244502     2024-03-19 14:00:00             NaN
# way/998244503     2024-03-19 14:00:00             NaN
#
#                                                                               name  \
# @osmId            @snapshotTimestamp
# relation/10116799 2024-03-19 14:00:00                   Lichtenauer Rheinniederung
# relation/10168615 2024-03-19 14:00:00                                  Kaltenbronn
# relation/10830286 2024-03-19 14:00:00                                          NaN
# relation/11267834 2024-03-19 14:00:00                                    Schurwald
# relation/11283442 2024-03-19 14:00:00                       Ersinger Springenhalde
# ...                                                                            ...
# way/9955306       2024-03-19 14:00:00        Kleingartenanlage Benswiesen / Mörsch
# way/99578434      2024-03-19 14:00:00         Gruppenwasserversorgung Balzhofen 16
# way/99578437      2024-03-19 14:00:00         Gruppenwasserversorgung Balzhofen 16
# way/998244502     2024-03-19 14:00:00  Klinge, Hohlweg, Feldgehölz und zwei Eichen
# way/998244503     2024-03-19 14:00:00                   Feuchtgebiet am Brüdenbach
#
#                                       protect_class  \
# @osmId            @snapshotTimestamp
# relation/10116799 2024-03-19 14:00:00             4
# relation/10168615 2024-03-19 14:00:00             4
# relation/10830286 2024-03-19 14:00:00            22
# relation/11267834 2024-03-19 14:00:00            97
# relation/11283442 2024-03-19 14:00:00             4
# ...                                             ...
# way/9955306       2024-03-19 14:00:00           NaN
# way/99578434      2024-03-19 14:00:00            12
# way/99578437      2024-03-19 14:00:00            12
# way/998244502     2024-03-19 14:00:00             7
# way/998244503     2024-03-19 14:00:00             7
#
#                                                        protection_title  ...  \
# @osmId            @snapshotTimestamp                                     ...
# relation/10116799 2024-03-19 14:00:00                 Naturschutzgebiet  ...
# relation/10168615 2024-03-19 14:00:00                 Naturschutzgebiet  ...
# relation/10830286 2024-03-19 14:00:00                      Gesamtanlage  ...
# relation/11267834 2024-03-19 14:00:00               Fauna-Flora-Habitat  ...
# relation/11283442 2024-03-19 14:00:00                 Naturschutzgebiet  ...
# ...                                                                 ...  ...
# way/9955306       2024-03-19 14:00:00                               NaN  ...
# way/99578434      2024-03-19 14:00:00   Wasserschutzgebiet-Schutzzone I  ...
# way/99578437      2024-03-19 14:00:00  Wasserschutzgebiet-Schutzzone II  ...
# way/998244502     2024-03-19 14:00:00                      Naturdenkmal  ...
# way/998244503     2024-03-19 14:00:00                      Naturdenkmal  ...
#
#                                       religion lad:criteria protection_aim  \
# @osmId            @snapshotTimestamp
# relation/10116799 2024-03-19 14:00:00      NaN          NaN            NaN
# relation/10168615 2024-03-19 14:00:00      NaN          NaN            NaN
# relation/10830286 2024-03-19 14:00:00      NaN          NaN            NaN
# relation/11267834 2024-03-19 14:00:00      NaN          NaN            NaN
# relation/11283442 2024-03-19 14:00:00      NaN          NaN            NaN
# ...                                        ...          ...            ...
# way/9955306       2024-03-19 14:00:00      NaN          NaN            NaN
# way/99578434      2024-03-19 14:00:00      NaN          NaN            NaN
# way/99578437      2024-03-19 14:00:00      NaN          NaN            NaN
# way/998244502     2024-03-19 14:00:00      NaN          NaN            NaN
# way/998244503     2024-03-19 14:00:00      NaN          NaN            NaN
#
#                                       fence_type trees man_made openfire  \
# @osmId            @snapshotTimestamp
# relation/10116799 2024-03-19 14:00:00        NaN   NaN      NaN      NaN
# relation/10168615 2024-03-19 14:00:00        NaN   NaN      NaN      NaN
# relation/10830286 2024-03-19 14:00:00        NaN   NaN      NaN      NaN
# relation/11267834 2024-03-19 14:00:00        NaN   NaN      NaN      NaN
# relation/11283442 2024-03-19 14:00:00        NaN   NaN      NaN      NaN
# ...                                          ...   ...      ...      ...
# way/9955306       2024-03-19 14:00:00        NaN   NaN      NaN      NaN
# way/99578434      2024-03-19 14:00:00        NaN   NaN      NaN      NaN
# way/99578437      2024-03-19 14:00:00        NaN   NaN      NaN      NaN
# way/998244502     2024-03-19 14:00:00        NaN   NaN      NaN      NaN
# way/998244503     2024-03-19 14:00:00        NaN   NaN      NaN      NaN
#
#                                       comment bicycle protected_area
# @osmId            @snapshotTimestamp
# relation/10116799 2024-03-19 14:00:00     NaN     NaN            NaN
# relation/10168615 2024-03-19 14:00:00     NaN     NaN            NaN
# relation/10830286 2024-03-19 14:00:00     NaN     NaN            NaN
# relation/11267834 2024-03-19 14:00:00     NaN     NaN            NaN
# relation/11283442 2024-03-19 14:00:00     NaN     NaN            NaN
# ...                                       ...     ...            ...
# way/9955306       2024-03-19 14:00:00     NaN     NaN            NaN
# way/99578434      2024-03-19 14:00:00     NaN     NaN            NaN
# way/99578437      2024-03-19 14:00:00     NaN     NaN            NaN
# way/998244502     2024-03-19 14:00:00     NaN     NaN            NaN
# way/998244503     2024-03-19 14:00:00     NaN     NaN            NaN
#
# [1347 rows x 157 columns]

# %% [markdown]
# # Grid

# %%
import geopandas as gpd
import geohexgrid as ghg
import matplotlib.pyplot as plt

# Load Baden-Württemberg territorial authorities
bw = gpd.read_file("../data/input/baden_wuerttemberg.geojson")

# Reproject to EPSG 25832 (ETRS89 / UTM Zone 32N)
bw = bw.to_crs(epsg=25832)

# Cover it minimally with hexagons of circumradius 10 kilometres
grid = ghg.make_grid_from_gdf(bw, R=10_000)

# Save the grid as GeoJSON
grid.to_file("../data/output/grid.geojson", driver="GeoJSON")

# Check data
print("Number of records in grid:", len(grid))

# Calculate centroids of hexagons
centroids = grid.geometry.centroid

# Save the centroids as GeoJSON
centroids_gdf = gpd.GeoDataFrame(geometry=centroids)
centroids_gdf.to_file("../data/output/centroids_grid.geojson", driver="GeoJSON")

# Plot
fig, ax = plt.subplots(figsize=(10, 10))
bw.plot(ax=ax, color="black")
grid.plot(ax=ax, color="white", edgecolor="red", alpha=0.5)
centroids.plot(ax=ax, color="orange", markersize=5)

# Remove axis
ax.axis('off')

# Display the plot
plt.show()

# Save the plot to a file using fig.savefig()
fig.savefig("../plots/baden_wuerttemberg_grid_centroid.png", dpi=300, bbox_inches="tight")

# %% [markdown]
# # Centroids

# %%
import json
import pyproj
from pyproj import Proj

# Define the target CRS (WGS84, EPSG:4326) for latitude and longitude
target_crs = Proj('epsg:4326')

# Open the GeoJSON file
with open('../data/output/centroids_grid.geojson') as f:
    data = json.load(f)

# Initialize the ID counter
id_counter = 1

# Initialize the transformer for coordinate transformation
transformer = pyproj.Transformer.from_proj(Proj('epsg:25832'), target_crs)

# Iterate over features and calculate longitude and latitude
for feature in data['features']:
    # Assign an ongoing ID to each feature
    feature['properties']['id'] = id_counter
    id_counter += 1
    
    # Extract coordinates
    coordinates = feature['geometry']['coordinates']
    # Transform coordinates to longitude and latitude
    longitude, latitude = transformer.transform(coordinates[0], coordinates[1])
    # Add longitude and latitude as separate properties
    feature['properties']['longitude'] = longitude
    feature['properties']['latitude'] = latitude

# Save the modified GeoJSON data back to a new file
with open('../data/output/centroids_with_coordinates.geojson', 'w') as f:
    json.dump(data, f)

print("Longitude and latitude calculated, IDs assigned, and saved to centroids_with_coordinates.geojson.")

# %% [markdown]
# # Data processing

# %% [markdown]
# ## Cleaning the data

# %% [markdown]
# ### the column headers have a ":" in the name which creates troubles for further analysis

# %%
import geopandas as gpd

# Load power plants GeoJSON file
power_plants = gpd.read_file("../data/output/powerplants.geojson")

# Replace the colon (:) with an underscore (_) in the column name
power_plants.columns = power_plants.columns.str.replace(':', '_')

# Save the modified GeoDataFrame to a new GeoJSON file
power_plants.to_file("../data/output/powerplants_name.geojson", driver='GeoJSON')

# Load the modified GeoDataFrame from the new file
power_plants_modified = gpd.read_file("../data/output/powerplants_name.geojson")

# Print all column names for the new file
print("\nModified Column Names:")
for col in power_plants_modified.columns:
    print(col)
# Out:
# Modified Column Names:
# @osmId
# @snapshotTimestamp
# @changesetId
# @lastEdit
# @osmType
# @version
# name
# operator
# operator_wikidata
# plant_method
# plant_output_electricity
# plant_source
# power
# start_date
# type
# description
# plant_output_hot_water
# website
# site
# generator_method
# generator_output_electricity
# generator_source
# generator_type
# barrier
# wikidata
# wikimedia_commons
# building
# layer
# plant_type
# landuse
# opening_date
# wikipedia
# construction_start_date
# note
# source
# old_operator
# frequency
# voltage
# addr_city
# addr_country
# addr_housenumber
# addr_postcode
# addr_street
# manufacturer
# location
# addr_place
# alt_name
# ref_bna
# addr_suburb
# plant_output_heat
# ref_EU_ENTSOE_EIC
# contact_website
# short_name
# construction_plant_method
# construction_plant_output_electricity
# construction_plant_source
# construction_plant_storage
# fixme
# planned_plant_storage
# plant_storage
# heritage
# heritage_operator
# historic
# ruins
# building_material
# building_name
# height
# plant_output_cold_water
# waterway
# old_name
# plant_output_steam
# source_geometry
# usage
# access
# roof_shape
# plant_output_biogas
# ref
# owner
# start_date_commercially_power_production
# construction
# industrial
# proposed
# roof_colour
# roof_material
# utility
# plant_source_biomass
# man_made
# url
# name_fr
# plant_solar_modules
# generator_output_heat
# addr_state
# natural
# tourism
# water
# official_name
# source_outline
# building_levels
# roof_levels
# surveillance
# image
# name_en
# name_en_note
# opening_hours
# operator_wikipedia
# surface
# ref_EEG
# fence_type
# building_min_level
# plant_output_gas
# source_plant_output_electricity
# check_date
# addr_hamlet
# addr_housename
# plant_source_gas
# geometry

# %% [markdown]
# ## Calculating the area for the water polygons

# %%
import geopandas as gpd

# Load water GeoJSON file
water_gdf = gpd.read_file("../data/output/water.geojson")

# Filter out geometries that are polygons and create a copy
water_polygons = water_gdf[water_gdf['geometry'].geom_type == 'Polygon'].copy()

# Replace the colon (:) with an underscore (_) in the column names
water_polygons.columns = water_polygons.columns.str.replace(':', '_')

# Reproject the geometries to EPSG:25832
water_polygons = water_polygons.to_crs(epsg=25832)

# Calculate the area for each polygon and store it in a new column
water_polygons['area'] = water_polygons['geometry'].area

# Save the GeoDataFrame with polygons and the calculated area to a new GeoJSON file
water_polygons.to_file("../data/output/water_area.geojson", driver='GeoJSON')

# %% [markdown]
# ## Clip to grid

# %% [markdown]
# ### clipping nature reserve

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Polygon
import matplotlib.pyplot as plt
import warnings

# Suppress the FutureWarning
warnings.simplefilter(action='ignore', category=FutureWarning)

# Load hexagon grid and nature reserve data
hexagon_grid = gpd.read_file('../data/output/grid.geojson')
nature_reserve = gpd.read_file('../data/output/nature_reserve.geojson')

# Reproject geometries to a UTM CRS
nature_reserve = nature_reserve.to_crs("EPSG:25832")

# Clip nature reserve polygons at the borders of hexagons
clipped_nature_reserve = gpd.overlay(nature_reserve, hexagon_grid, how='intersection', keep_geom_type=False)

# Save the result
clipped_nature_reserve.to_file('../data/output/clipped_nature_reserve.geojson', driver='GeoJSON')

# Read the clipped nature reserve GeoJSON file
clipped_nature_reserve = gpd.read_file('../data/output/clipped_nature_reserve.geojson')

# Plot the clipped nature reserve
fig, ax = plt.subplots(figsize=(10, 10))
clipped_nature_reserve.plot(ax=ax, color='green', edgecolor='green')
ax.set_title('Clipped Nature Reserve')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# Save the plot to a file using fig.savefig()
fig.savefig("../plots/clipped_nature_reserves.png", dpi=300, bbox_inches="tight")

# %% [markdown]
# ### clipping protected area

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Polygon
import matplotlib.pyplot as plt
import warnings

# Suppress the FutureWarning
warnings.simplefilter(action='ignore', category=FutureWarning)

# Load hexagon grid and protected area
hexagon_grid = gpd.read_file('../data/output/grid.geojson')
protected_area = gpd.read_file('../data/output/protected_area_reclass.geojson')

# Reproject geometries to a UTM CRS
protected_area = protected_area.to_crs("EPSG:25832")

# Clip protectedvarea polygons at the borders of hexagons
clipped_protected_area = gpd.overlay(protected_area, hexagon_grid, how='intersection', keep_geom_type=False)

# Save the result
clipped_protected_area.to_file('../data/output/clipped_protected_area.geojson', driver='GeoJSON')

# Read the clipped protected_area GeoJSON file
clipped_protected_area = gpd.read_file('../data/output/clipped_protected_area.geojson')

# Plot the clipped protected_area and hexagon grid
fig, ax = plt.subplots(figsize=(10, 10))
clipped_protected_area.plot(ax=ax, color='maroon', edgecolor='maroon')
hexagon_grid.plot(ax=ax, facecolor='none', edgecolor='grey')
ax.set_title('Clipped Protected Areas with Hexagon Grid')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# Save the plot to a file using fig.savefig()
fig.savefig("../plots/clipped_protected_area_with_grid.png", dpi=300, bbox_inches="tight")

# %% [markdown]
# ## Distance centroids to factors

# %% [markdown]
# ### add distance to nearest telecom point to centroids

# %%
import geopandas as gpd
from shapely.ops import nearest_points

# Load centroids and telecom points data with GeoPandas
centroids = gpd.read_file('../data/output/centroids_with_coordinates.geojson')
telecom_points = gpd.read_file('../data/output/telecom_points.geojson')

# Reproject to EPSG:25832
centroids = centroids.to_crs(epsg=25832)
telecom_points = telecom_points.to_crs(epsg=25832)

# Calculate distance between each centroid and the nearest telecom point
distances = []
nearest_telecom = []

for idx, centroid in centroids.iterrows():
    nearest_point = nearest_points(centroid.geometry, telecom_points.unary_union)[1]
    distance = centroid.geometry.distance(nearest_point)
    distances.append(distance)
    nearest_telecom.append(telecom_points.iloc[telecom_points.distance(nearest_point).idxmin()]['telecom'])

# Add the distances and nearest telecom information to the centroids dataframe
centroids['distance_to_telecom'] = distances
centroids['nearest_telecom'] = nearest_telecom

# Create a new GeoDataFrame with distance and telecom information
telecom_distance = centroids[['id', 'geometry', 'longitude', 'latitude', 'distance_to_telecom', 'nearest_telecom']]

# Save the GeoDataFrame to GeoJSON
telecom_distance.to_file('../data/output/telecom_distance.geojson', driver='GeoJSON')

# %% [markdown]
# ### add distance to nearest power plant

# %%
import geopandas as gpd
import pandas as pd
from shapely.ops import nearest_points

# Load centroids and power plants data with GeoPandas
centroids = gpd.read_file('../data/output/telecom_distance.geojson')
powerplants = gpd.read_file('../data/output/powerplants_name.geojson')

# Reproject both datasets to a projected CRS (e.g., EPSG:25832)
centroids = centroids.to_crs(epsg=25832)
powerplants = powerplants.to_crs(epsg=25832)

# Calculate centroids of power plant polygons
powerplant_centroids = powerplants.copy()
powerplant_centroids['geometry'] = powerplant_centroids['geometry'].centroid

# Calculate distance between each centroid and the nearest power plant
distances = []
for idx, centroid in centroids.iterrows():
    nearest_point = nearest_points(centroid.geometry, powerplant_centroids.unary_union)[1]
    distance = centroid.geometry.distance(nearest_point)
    distances.append(distance)

# Add the distances to the centroids dataframe
centroids['distance_to_powerplant'] = distances

# Merge power plant information into centroids dataframe based on the nearest plant
nearest_plant_info = []
for idx, centroid in centroids.iterrows():
    nearest_plant = powerplant_centroids.iloc[powerplant_centroids.distance(centroid.geometry).idxmin()]
    nearest_plant_info.append(nearest_plant[['plant_method', 'plant_source', 'name']])

nearest_plant_info_df = pd.DataFrame(nearest_plant_info, columns=['plant_method', 'plant_source', 'name'])
centroids.reset_index(drop=True, inplace=True)  # Reset index to avoid non-unique index values
nearest_plant_info_df.reset_index(drop=True, inplace=True)  # Reset index to avoid non-unique index values
centroids_with_info = pd.concat([centroids, nearest_plant_info_df], axis=1)

# Save the GeoDataFrame to GeoJSON
centroids_with_info.to_file('../data/output/powerplant_distance.geojson', driver='GeoJSON')

# %% [markdown]
# ### add distance to powerlines

# %%
import geopandas as gpd
from shapely.ops import nearest_points

# Load centroids and power lines data with GeoPandas
centroids = gpd.read_file('../data/output/powerplant_distance.geojson')
powerlines = gpd.read_file('../data/output/powerlines.geojson')

# Reproject both datasets to a projected CRS (e.g., EPSG:25832)
centroids = centroids.to_crs(epsg=25832)
powerlines = powerlines.to_crs(epsg=25832)

# Calculate distance between each centroid and the nearest power line
distances = []
for idx, centroid in centroids.iterrows():
    nearest_point = nearest_points(centroid.geometry, powerlines.unary_union)[1]
    distance = centroid.geometry.distance(nearest_point)
    distances.append(distance)

# Add the distances to the centroids dataframe
centroids['distance_to_powerline'] = distances

# Save the GeoDataFrame to GeoJSON
centroids.to_file('../data/output/powerlines_distance.geojson', driver='GeoJSON')

print("Distance calculation and saving completed.")
# Out:
# /Users/celinathome/anaconda3/lib/python3.11/site-packages/geopandas/io/file.py:364: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   as_dt = pd.to_datetime(df[k], errors="ignore")
# /Users/celinathome/anaconda3/lib/python3.11/site-packages/geopandas/io/file.py:364: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   as_dt = pd.to_datetime(df[k], errors="ignore")
# Distance calculation and saving completed.

# %% [markdown]
# ### add distance to water

# %%
import geopandas as gpd
import pandas as pd
from shapely.ops import nearest_points

# Load centroids and power plants data with GeoPandas
centroids = gpd.read_file('../data/output/powerlines_distance.geojson')
water_area = gpd.read_file('../data/output/water_area.geojson')

# Reproject both datasets to a projected CRS (e.g., EPSG:25832)
centroids = centroids.to_crs(epsg=25832)
water_area = water_area.to_crs(epsg=25832)

# Calculate centroids of power plant polygons
water_area_centroids = water_area.copy()
water_area_centroids['geometry'] = water_area_centroids['geometry'].centroid

# Calculate distance between each centroid and the nearest power plant
distances = []
for idx, centroid in centroids.iterrows():
    nearest_point = nearest_points(centroid.geometry, water_area_centroids.unary_union)[1]
    distance = centroid.geometry.distance(nearest_point)
    distances.append(distance)

# Add the distances to the centroids dataframe
centroids['distance_to_water'] = distances

# Merge power plant information into centroids dataframe based on the nearest plant
nearest_water_info = []
for idx, centroid in centroids.iterrows():
    nearest_water = water_area_centroids.iloc[water_area_centroids.distance(centroid.geometry).idxmin()]
    nearest_water_info.append(nearest_water[['area', 'water']])

nearest_water_info_df = pd.DataFrame(nearest_water_info, columns=['area', 'water'])
centroids.reset_index(drop=True, inplace=True)  # Reset index to avoid non-unique index values
nearest_water_info_df.reset_index(drop=True, inplace=True)  # Reset index to avoid non-unique index values
centroids_with_info = pd.concat([centroids, nearest_water_info_df], axis=1)

# Save the GeoDataFrame to GeoJSON
centroids_with_info.to_file('../data/output/water_distance.geojson', driver='GeoJSON')
# Out:
# /Users/celinathome/anaconda3/lib/python3.11/site-packages/geopandas/io/file.py:364: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   as_dt = pd.to_datetime(df[k], errors="ignore")
# /Users/celinathome/anaconda3/lib/python3.11/site-packages/geopandas/io/file.py:364: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   as_dt = pd.to_datetime(df[k], errors="ignore")

# %% [markdown]
# ### add if in protected area

# %%
import geopandas as gpd

# Load hexagon grid and protected areas data
grid = gpd.read_file('../data/output/grid.geojson')
protected_areas = gpd.read_file('../data/output/clipped_protected_area.geojson')

# Perform spatial join to identify which hexagons intersect with protected areas
grid_with_protected_areas = gpd.sjoin(grid, protected_areas, how='left', op='intersects')

# Select necessary columns from the joined dataset
selected_columns = ['geometry', 'protect_class', 'reclass_protect_class']

# Save the result to a new GeoJSON file
grid_with_protected_areas[selected_columns].to_file('../data/output/grid_with_protected_areas.geojson', driver='GeoJSON')

# %%
import geopandas as gpd

# Load grid_with_protected_areas.geojson
grid_with_protected_areas = gpd.read_file('../data/output/grid_with_protected_areas.geojson')

# Load centroids_with_coordinates.geojson
centroids = gpd.read_file('../data/output/centroids_with_coordinates.geojson')

# Perform spatial join to identify centroids within hexagons
joined_data = gpd.sjoin(grid_with_protected_areas, centroids, how='left')

# Drop the index_right column
joined_data.drop(columns=['index_right'], inplace=True)

# Save the result to a new GeoJSON file
joined_data.to_file('../data/output/grid_with_protected_areas_with_centroid_id.geojson', driver='GeoJSON')

# %% [markdown]
# # Calculate isochrones

# %% [markdown]
# ## for car

# %%
import json
import time
import os
import geopandas as gpd
from openrouteservice import Client
from openrouteservice.exceptions import ApiError

# Load centroids data with GeoPandas
centroids = gpd.read_file('../data/output/centroids_with_coordinates.geojson')

# Change CRS to EPSG:4326
centroids = centroids.to_crs("EPSG:4326")

# Initialize OpenRouteService client
api_key = "YOUR-API-KEY"  # Replace with your actual API key. Get it by logging in here: https://openrouteservice.org/log-in/
client = Client(key=api_key)

# Define parameters for isochrone calculation
profile = 'driving-car'
range_type = 'time'
range_seconds = [600, 1200, 1800, 2700, 3600]  # Define desired time ranges in seconds

# Directory to save isochrones files
output_directory = '../data/output/isochrones_car/'

# Create the directory if it doesn't exist
os.makedirs(output_directory, exist_ok=True)

# Function to calculate isochrones with retry mechanism
def calculate_isochrones_with_retry(coordinate):
    retries = 3  # Number of retries
    for attempt in range(retries):
        try:
            isochrones = client.isochrones(locations=[coordinate], profile=profile, range_type=range_type, range=range_seconds, attributes=['total_pop'])
            return isochrones
        except ApiError as e:
            if "rate limit exceeded" in str(e):
                print(f"Rate limit exceeded. Retrying in 10 seconds...")
                time.sleep(10)  # Retry after 10 seconds for rate limit errors
            elif "Unable to build an isochrone map" in str(e):
                print(f"Unable to build an isochrone map for centroid. Skipping...")
                return None
            else:
                raise e  # Re-raise the exception if it's not related to rate limit exceeded
    return None

# Iterate over centroids and calculate isochrones
for idx, row in centroids.iterrows():
    # Get coordinates of the centroid
    lon, lat = row['geometry'].x, row['geometry'].y
    coordinate = (lon, lat)

    # Calculate isochrones with retry mechanism
    isochrones = calculate_isochrones_with_retry(coordinate)
    if isochrones is None:
        continue  # Skip the centroid if isochrones cannot be calculated

    # Save isochrones data to file
    output_filename = os.path.join(output_directory, f'isochrones_{row["id"]}.geojson')
    with open(output_filename, 'w') as output_file:
        json.dump(isochrones, output_file)

    print(f"Isochrones calculated for centroid {row['id']}")

    # Rate limit handling
    time.sleep(3)  # Add a small delay to avoid rate limits and respect the rate limit

print("Isochrone calculation completed.")

# Plot centroids and isochrones
fig, ax = plt.subplots(figsize=(10, 10))

# Plot centroids
centroids.plot(ax=ax, color='red', markersize=50, alpha=0.7, label='Centroids')

# Plot isochrones
for idx, row in centroids.iterrows():
    isochrone_file = os.path.join(output_directory, f'isochrones_{row["id"]}.geojson')
    isochrones = gpd.read_file(isochrone_file)
    isochrones.plot(ax=ax, alpha=0.5, linewidth=2)

# Set title and legend
ax.set_title('Isochrones for Cars')
ax.legend()

# Save the plot
plt.savefig('../plots/isochrones_car_map.png')

# Show plot
plt.show()
# Out:
# Isochrones calculated for centroid 1
# Isochrones calculated for centroid 2
# Isochrones calculated for centroid 3
# Isochrones calculated for centroid 4
# Isochrones calculated for centroid 5
# Isochrones calculated for centroid 6
# Isochrones calculated for centroid 7
# Isochrones calculated for centroid 8
# Isochrones calculated for centroid 9
# Unable to build an isochrone map for centroid. Skipping...
# Isochrones calculated for centroid 11
# Unable to build an isochrone map for centroid. Skipping...
# Isochrones calculated for centroid 13
# Isochrones calculated for centroid 14
# Isochrones calculated for centroid 15
# Isochrones calculated for centroid 16
# Isochrones calculated for centroid 17
# Isochrones calculated for centroid 18
# Isochrones calculated for centroid 19
# Isochrones calculated for centroid 20
# Isochrones calculated for centroid 21
# Isochrones calculated for centroid 22
# Isochrones calculated for centroid 23
# Isochrones calculated for centroid 24
# Isochrones calculated for centroid 25
# Isochrones calculated for centroid 26
# Isochrones calculated for centroid 27
# Isochrones calculated for centroid 28
# Isochrones calculated for centroid 29
# Isochrones calculated for centroid 30
# Isochrones calculated for centroid 31
# Isochrones calculated for centroid 32
# Unable to build an isochrone map for centroid. Skipping...
# Isochrones calculated for centroid 34
# Isochrones calculated for centroid 35
# Isochrones calculated for centroid 36
# Isochrones calculated for centroid 37
# Isochrones calculated for centroid 38
# Isochrones calculated for centroid 39
# Isochrones calculated for centroid 40
# Isochrones calculated for centroid 41
# Isochrones calculated for centroid 42
# Isochrones calculated for centroid 43
# Isochrones calculated for centroid 44
# Isochrones calculated for centroid 45
# Isochrones calculated for centroid 46
# Isochrones calculated for centroid 47
# Isochrones calculated for centroid 48
# Isochrones calculated for centroid 49
# Isochrones calculated for centroid 50
# Isochrones calculated for centroid 51
# Isochrones calculated for centroid 52
# Isochrones calculated for centroid 53
# Isochrones calculated for centroid 54
# Isochrones calculated for centroid 55
# Isochrones calculated for centroid 56
# Isochrones calculated for centroid 57
# Isochrones calculated for centroid 58
# Isochrones calculated for centroid 59
# Isochrones calculated for centroid 60
# Isochrones calculated for centroid 61
# Isochrones calculated for centroid 62
# Isochrones calculated for centroid 63
# Isochrones calculated for centroid 64
# Isochrones calculated for centroid 65
# Isochrones calculated for centroid 66
# Isochrones calculated for centroid 67
# Isochrones calculated for centroid 68
# Isochrones calculated for centroid 69
# Isochrones calculated for centroid 70
# Isochrones calculated for centroid 71
# Isochrones calculated for centroid 72
# Isochrones calculated for centroid 73
# Isochrones calculated for centroid 74
# Isochrones calculated for centroid 75
# Isochrones calculated for centroid 76
# Isochrones calculated for centroid 77
# Isochrones calculated for centroid 78
# Isochrones calculated for centroid 79
# Isochrones calculated for centroid 80
# Isochrones calculated for centroid 81
# Isochrones calculated for centroid 82
# Unable to build an isochrone map for centroid. Skipping...
# Isochrones calculated for centroid 84
# Isochrones calculated for centroid 85
# Isochrones calculated for centroid 86
# Isochrones calculated for centroid 87
# Isochrones calculated for centroid 88
# Isochrones calculated for centroid 89
# Isochrones calculated for centroid 90
# Isochrones calculated for centroid 91
# Isochrones calculated for centroid 92
# Isochrones calculated for centroid 93
# Isochrones calculated for centroid 94
# Isochrones calculated for centroid 95
# Isochrones calculated for centroid 96
# Unable to build an isochrone map for centroid. Skipping...
# Isochrones calculated for centroid 98
# Isochrones calculated for centroid 99
# Isochrones calculated for centroid 100
# Isochrones calculated for centroid 101
# Isochrones calculated for centroid 102
# Isochrones calculated for centroid 103
# Isochrones calculated for centroid 104
# Isochrones calculated for centroid 105
# Isochrones calculated for centroid 106
# Isochrones calculated for centroid 107
# Isochrones calculated for centroid 108
# Isochrones calculated for centroid 109
# Isochrones calculated for centroid 110
# Isochrones calculated for centroid 111
# Isochrones calculated for centroid 112
# Isochrones calculated for centroid 113
# Isochrones calculated for centroid 114
# Isochrones calculated for centroid 115
# Isochrones calculated for centroid 116
# Isochrones calculated for centroid 117
# Unable to build an isochrone map for centroid. Skipping...
# Isochrones calculated for centroid 119
# Isochrones calculated for centroid 120
# Isochrones calculated for centroid 121
# Isochrones calculated for centroid 122
# Isochrones calculated for centroid 123
# Isochrones calculated for centroid 124
# Isochrones calculated for centroid 125
# Isochrones calculated for centroid 126
# Isochrones calculated for centroid 127
# Isochrones calculated for centroid 128
# Unable to build an isochrone map for centroid. Skipping...
# Isochrones calculated for centroid 130
# Isochrones calculated for centroid 131
# Isochrones calculated for centroid 132
# Isochrones calculated for centroid 133
# Isochrones calculated for centroid 134
# Isochrones calculated for centroid 135
# Isochrones calculated for centroid 136
# Isochrones calculated for centroid 137
# Isochrones calculated for centroid 138
# Isochrones calculated for centroid 139
# Isochrones calculated for centroid 140
# Isochrones calculated for centroid 141
# Isochrones calculated for centroid 142
# Isochrones calculated for centroid 143
# Isochrones calculated for centroid 144
# Isochrones calculated for centroid 145
# Isochrones calculated for centroid 146
# Isochrones calculated for centroid 147
# Isochrones calculated for centroid 148
# Isochrones calculated for centroid 149
# Isochrones calculated for centroid 150
# Isochrones calculated for centroid 151
# Isochrones calculated for centroid 152
# Isochrones calculated for centroid 153
# Isochrones calculated for centroid 154
# Isochrones calculated for centroid 155
# Isochrones calculated for centroid 156
# Isochrones calculated for centroid 157
# Unable to build an isochrone map for centroid. Skipping...
# Isochrones calculated for centroid 159
# Isochrones calculated for centroid 160
# Isochrones calculated for centroid 161
# Isochrones calculated for centroid 162
# Isochrones calculated for centroid 163
# Isochrones calculated for centroid 164
# Isochrones calculated for centroid 165
# Isochrones calculated for centroid 166
# Isochrones calculated for centroid 167
# Isochrones calculated for centroid 168
# Isochrones calculated for centroid 169
# Isochrones calculated for centroid 170
# Isochrones calculated for centroid 171
# Isochrones calculated for centroid 172
# Isochrones calculated for centroid 173
# Isochrones calculated for centroid 174
# Isochrones calculated for centroid 175
# Isochrone calculation completed.

# %% [markdown]
# ## for bike

# %%
import json
import time
import os
import geopandas as gpd
from openrouteservice import Client
from openrouteservice.exceptions import ApiError
import matplotlib.pyplot as plt

# Load centroids data with GeoPandas
centroids = gpd.read_file('../data/output/centroids_with_coordinates.geojson')

# Change CRS to EPSG:4326
centroids = centroids.to_crs("EPSG:4326")

# Initialize OpenRouteService client
api_key = "YOUR-API-KEY"  # Replace with your actual API key
client = Client(key=api_key)

# Define parameters for isochrone calculation
profile = 'cycling-regular'  # Bike profile
range_type = 'time'
range_seconds = [600, 1200, 1800, 2700, 3600]  # All isochrones with the same time range (10 minutes)

# Directory to save isochrones files
output_directory = '../data/output/isochrones_bike/'

# Create the directory if it doesn't exist
os.makedirs(output_directory, exist_ok=True)

# Function to calculate isochrones with retry mechanism
def calculate_isochrones_with_retry(coordinate):
    retries = 3  # Number of retries
    for attempt in range(retries):
        try:
            isochrones = client.isochrones(locations=[coordinate], profile=profile, range_type=range_type, range=range_seconds, attributes=['total_pop'])
            return isochrones
        except ApiError as e:
            if "rate limit exceeded" in str(e):
                print(f"Rate limit exceeded. Retrying in 10 seconds...")
                time.sleep(10)  # Retry after 10 seconds for rate limit errors
            elif "Unable to build an isochrone map" in str(e):
                print(f"Unable to build an isochrone map for centroid. Skipping...")
                return None
            else:
                raise e  # Re-raise the exception if it's not related to rate limit exceeded
    return None

# Iterate over centroids and calculate isochrones
for idx, row in centroids.iterrows():
    # Get coordinates of the centroid
    lon, lat = row['geometry'].x, row['geometry'].y
    coordinate = (lon, lat)

    # Calculate isochrones with retry mechanism
    isochrones = calculate_isochrones_with_retry(coordinate)
    if isochrones is None:
        continue  # Skip the centroid if isochrones cannot be calculated

    # Save isochrones data to file
    output_filename = os.path.join(output_directory, f'isochrones_{row["id"]}.geojson')
    with open(output_filename, 'w') as output_file:
        json.dump(isochrones, output_file)

    print(f"Isochrones calculated for centroid {row['id']}")

    # Rate limit handling
    time.sleep(3)  # Add a small delay to avoid rate limits and respect the rate limit

print("Isochrone calculation for biking completed.")

# Plot centroids and isochrones
fig, ax = plt.subplots(figsize=(10, 10))

# Plot centroids
centroids.plot(ax=ax, color='red', markersize=50, alpha=0.7, label='Centroids')

# Plot isochrones
for idx, row in centroids.iterrows():
    isochrone_file = os.path.join(output_directory, f'isochrones_{row["id"]}.geojson')
    isochrones = gpd.read_file(isochrone_file)
    isochrones.plot(ax=ax, alpha=0.5, linewidth=2)

# Set title and legend
ax.set_title('Isochrones for Bike Profile')
ax.legend()

# Save the plot
plt.savefig('../plots/isochrones_bike_map.png')

# Show plot
plt.show()
# Out:
# Isochrones calculated for centroid 1
# Isochrones calculated for centroid 2
# Isochrones calculated for centroid 3
# Isochrones calculated for centroid 4
# Isochrones calculated for centroid 5
# Isochrones calculated for centroid 6
# Isochrones calculated for centroid 7
# Isochrones calculated for centroid 8
# Isochrones calculated for centroid 9
# Isochrones calculated for centroid 10
# Isochrones calculated for centroid 11
# Isochrones calculated for centroid 12
# Isochrones calculated for centroid 13
# Isochrones calculated for centroid 14
# Isochrones calculated for centroid 15
# Isochrones calculated for centroid 16
# Isochrones calculated for centroid 17
# Isochrones calculated for centroid 18
# Isochrones calculated for centroid 19
# Isochrones calculated for centroid 20
# Isochrones calculated for centroid 21
# Isochrones calculated for centroid 22
# Isochrones calculated for centroid 23
# Isochrones calculated for centroid 24
# Isochrones calculated for centroid 25
# Isochrones calculated for centroid 26
# Isochrones calculated for centroid 27
# Isochrones calculated for centroid 28
# Isochrones calculated for centroid 29
# Isochrones calculated for centroid 30
# Isochrones calculated for centroid 31
# Isochrones calculated for centroid 32
# Isochrones calculated for centroid 33
# Isochrones calculated for centroid 34
# Isochrones calculated for centroid 35
# Isochrones calculated for centroid 36
# Isochrones calculated for centroid 37
# Isochrones calculated for centroid 38
# Isochrones calculated for centroid 39
# Isochrones calculated for centroid 40
# Isochrones calculated for centroid 41
# Isochrones calculated for centroid 42
# Isochrones calculated for centroid 43
# Isochrones calculated for centroid 44
# Isochrones calculated for centroid 45
# Isochrones calculated for centroid 46
# Isochrones calculated for centroid 47
# Isochrones calculated for centroid 48
# Isochrones calculated for centroid 49
# Isochrones calculated for centroid 50
# Isochrones calculated for centroid 51
# Isochrones calculated for centroid 52
# Isochrones calculated for centroid 53
# Isochrones calculated for centroid 54
# Isochrones calculated for centroid 55
# Isochrones calculated for centroid 56
# Isochrones calculated for centroid 57
# Isochrones calculated for centroid 58
# Isochrones calculated for centroid 59
# Isochrones calculated for centroid 60
# Isochrones calculated for centroid 61
# Isochrones calculated for centroid 62
# Isochrones calculated for centroid 63
# Isochrones calculated for centroid 64
# Isochrones calculated for centroid 65
# Isochrones calculated for centroid 66
# Isochrones calculated for centroid 67
# Isochrones calculated for centroid 68
# Isochrones calculated for centroid 69
# Isochrones calculated for centroid 70
# Isochrones calculated for centroid 71
# Isochrones calculated for centroid 72
# Isochrones calculated for centroid 73
# Isochrones calculated for centroid 74
# Isochrones calculated for centroid 75
# Isochrones calculated for centroid 76
# Isochrones calculated for centroid 77
# Isochrones calculated for centroid 78
# Isochrones calculated for centroid 79
# Isochrones calculated for centroid 80
# Isochrones calculated for centroid 81
# Isochrones calculated for centroid 82
# Isochrones calculated for centroid 83
# Isochrones calculated for centroid 84
# Isochrones calculated for centroid 85
# Isochrones calculated for centroid 86
# Isochrones calculated for centroid 87
# Isochrones calculated for centroid 88
# Isochrones calculated for centroid 89
# Isochrones calculated for centroid 90
# Isochrones calculated for centroid 91
# Isochrones calculated for centroid 92
# Isochrones calculated for centroid 93
# Isochrones calculated for centroid 94
# Isochrones calculated for centroid 95
# Isochrones calculated for centroid 96
# Isochrones calculated for centroid 97
# Isochrones calculated for centroid 98
# Isochrones calculated for centroid 99
# Isochrones calculated for centroid 100
# Isochrones calculated for centroid 101
# Isochrones calculated for centroid 102
# Isochrones calculated for centroid 103
# Isochrones calculated for centroid 104
# Isochrones calculated for centroid 105
# Isochrones calculated for centroid 106
# Isochrones calculated for centroid 107
# Isochrones calculated for centroid 108
# Isochrones calculated for centroid 109
# Isochrones calculated for centroid 110
# Isochrones calculated for centroid 111
# Isochrones calculated for centroid 112
# Isochrones calculated for centroid 113
# Isochrones calculated for centroid 114
# Isochrones calculated for centroid 115
# Isochrones calculated for centroid 116
# Isochrones calculated for centroid 117
# Isochrones calculated for centroid 118
# Isochrones calculated for centroid 119
# Isochrones calculated for centroid 120
# Isochrones calculated for centroid 121
# Isochrones calculated for centroid 122
# Isochrones calculated for centroid 123
# Isochrones calculated for centroid 124
# Isochrones calculated for centroid 125
# Isochrones calculated for centroid 126
# Isochrones calculated for centroid 127
# Isochrones calculated for centroid 128
# Isochrones calculated for centroid 129
# Isochrones calculated for centroid 130
# Isochrones calculated for centroid 131
# Isochrones calculated for centroid 132
# Isochrones calculated for centroid 133
# Isochrones calculated for centroid 134
# Isochrones calculated for centroid 135
# Isochrones calculated for centroid 136
# Isochrones calculated for centroid 137
# Isochrones calculated for centroid 138
# Isochrones calculated for centroid 139
# Isochrones calculated for centroid 140
# Isochrones calculated for centroid 141
# Isochrones calculated for centroid 142
# Isochrones calculated for centroid 143
# Isochrones calculated for centroid 144
# Isochrones calculated for centroid 145
# Isochrones calculated for centroid 146
# Isochrones calculated for centroid 147
# Isochrones calculated for centroid 148
# Isochrones calculated for centroid 149
# Isochrones calculated for centroid 150
# Isochrones calculated for centroid 151
# Isochrones calculated for centroid 152
# Isochrones calculated for centroid 153
# Isochrones calculated for centroid 154
# Isochrones calculated for centroid 155
# Isochrones calculated for centroid 156
# Isochrones calculated for centroid 157
# Isochrones calculated for centroid 158
# Isochrones calculated for centroid 159
# Isochrones calculated for centroid 160
# Isochrones calculated for centroid 161
# Isochrones calculated for centroid 162
# Isochrones calculated for centroid 163
# Isochrones calculated for centroid 164
# Isochrones calculated for centroid 165
# Isochrones calculated for centroid 166
# Isochrones calculated for centroid 167
# Isochrones calculated for centroid 168
# Isochrones calculated for centroid 169
# Isochrones calculated for centroid 170
# Isochrones calculated for centroid 171
# Isochrones calculated for centroid 172
# Isochrones calculated for centroid 173
# Isochrones calculated for centroid 174
# Isochrones calculated for centroid 175
# 2024-03-28 11:40:41,591  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:41,642  collection  WARNING:  Skipping field center: invalid type 3
# Isochrone calculation for biking completed.
# 2024-03-28 11:40:41,662  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:41,683  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:41,735  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:41,756  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:41,787  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:41,816  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:41,855  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:41,873  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:41,906  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:41,944  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:41,963  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:41,986  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,017  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,044  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,066  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,098  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,126  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,145  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,172  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,197  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,226  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,249  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,272  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,295  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,323  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,351  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,380  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,403  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,425  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,447  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,469  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,491  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,514  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,534  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,559  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,588  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,610  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,633  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,662  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,683  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,708  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,730  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,750  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,772  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,795  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,815  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,838  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,861  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,882  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,904  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,932  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,960  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:42,982  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,007  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,035  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,053  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,078  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,102  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,126  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,154  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,180  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,206  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,232  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,255  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,279  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,305  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,330  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,363  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,388  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,411  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,438  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,465  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,487  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,515  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,540  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,565  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,590  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,617  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,641  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,667  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,694  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,724  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,752  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,779  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,802  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,829  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,855  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,881  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,907  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,934  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,961  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:43,986  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,014  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,041  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,073  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,102  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,134  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,162  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,190  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,216  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,243  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,271  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,297  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,324  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,353  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,380  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,408  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,436  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,465  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,500  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,529  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,560  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,589  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,618  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,645  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,675  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,703  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,733  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,762  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,791  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,821  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,851  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,885  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,912  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,945  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:44,976  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,005  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,034  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,064  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,094  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,125  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,157  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,190  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,224  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,255  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,285  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,314  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,344  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,375  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,405  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,434  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,464  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,496  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,530  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,566  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,598  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,630  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,661  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,690  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,724  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,755  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,787  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,820  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,858  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,893  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,925  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,956  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:45,988  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:46,021  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:46,052  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:46,085  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:46,118  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:46,152  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:46,185  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:46,219  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:46,253  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:46,285  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:46,319  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:46,353  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:46,385  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:46,419  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:46,451  collection  WARNING:  Skipping field center: invalid type 3
# 2024-03-28 11:40:46,486  collection  WARNING:  Skipping field center: invalid type 3

# %% [markdown]
# ## for pedestrian

# %%
import json
import time
import os
import geopandas as gpd
from openrouteservice import Client
from openrouteservice.exceptions import ApiError
import matplotlib.pyplot as plt

# Load centroids data with GeoPandas
centroids = gpd.read_file('../data/output/centroids_with_coordinates.geojson')

# Change CRS to EPSG:4326
centroids = centroids.to_crs("EPSG:4326")  # Web Mercator projection

# Initialize OpenRouteService client
api_key = "5b3ce3597851110001cf6248ec8fc0286b4a4fd1a90fc8108327d823"  # Replace with your actual API key
client = Client(key=api_key)

# Define parameters for isochrone calculation
profile = 'foot-walking'  # Walking profile
range_type = 'time'
range_seconds = [600, 1200, 1800, 2700, 3600]  # Desired time ranges in seconds

# Directory to save isochrones files
output_directory = '../data/output/isochrones_walk/'

# Create the directory if it doesn't exist
os.makedirs(output_directory, exist_ok=True)

# Function to calculate isochrones with retry mechanism
def calculate_isochrones_with_retry(coordinate):
    retries = 3  # Number of retries
    for attempt in range(retries):
        try:
            isochrones = client.isochrones(locations=[coordinate], profile=profile, range_type=range_type, range=range_seconds, attributes=['total_pop'])
            return isochrones
        except ApiError as e:
            if "rate limit exceeded" in str(e):
                print(f"Rate limit exceeded. Retrying in 10 seconds...")
                time.sleep(10)  # Retry after 10 seconds for rate limit errors
            elif "Unable to build an isochrone map" in str(e):
                print(f"Unable to build an isochrone map for centroid. Skipping...")
                return None
            else:
                raise e  # Re-raise the exception if it's not related to rate limit exceeded
    return None

# Iterate over centroids and calculate isochrones
for idx, row in centroids.iterrows():
    # Get coordinates of the centroid
    lon, lat = row['geometry'].x, row['geometry'].y
    coordinate = (lon, lat)

    # Calculate isochrones with retry mechanism
    isochrones = calculate_isochrones_with_retry(coordinate)
    if isochrones is None:
        continue  # Skip the centroid if isochrones cannot be calculated

    # Save isochrones data to file
    output_filename = os.path.join(output_directory, f'isochrones_{row["id"]}.geojson')
    with open(output_filename, 'w') as output_file:
        json.dump(isochrones, output_file)

    print(f"Isochrones calculated for centroid {row['id']}")

    # Rate limit handling
    time.sleep(3)  # Add a small delay to avoid rate limits and respect the rate limit

print("Isochrone calculation for walking completed.")

# Plot centroids and isochrones
fig, ax = plt.subplots(figsize=(10, 10))

# Plot centroids
centroids.plot(ax=ax, color='blue', markersize=50, alpha=0.7, label='Centroids')

# Plot isochrones
for idx, row in centroids.iterrows():
    isochrone_file = os.path.join(output_directory, f'isochrones_{row["id"]}.geojson')
    isochrones = gpd.read_file(isochrone_file)
    isochrones.plot(ax=ax, alpha=0.5, linewidth=2)

# Set title and legend
ax.set_title('Isochrones for Walking Profile')
ax.legend()

# Save the plot
plt.savefig('../plots/isochrones_walk_map.png')

# Show plot
plt.show()
# Out:
# Isochrones calculated for centroid 1
# Isochrones calculated for centroid 2
# Isochrones calculated for centroid 3
# Isochrones calculated for centroid 4
# Isochrones calculated for centroid 5
# Isochrones calculated for centroid 6
# Isochrones calculated for centroid 7
# Isochrones calculated for centroid 8
# Isochrones calculated for centroid 9
# Isochrones calculated for centroid 10
# Isochrones calculated for centroid 11
# Isochrones calculated for centroid 12
# Isochrones calculated for centroid 13
# Isochrones calculated for centroid 14
# Isochrones calculated for centroid 15
# Isochrones calculated for centroid 16
# Isochrones calculated for centroid 17
# Isochrones calculated for centroid 18
# Isochrones calculated for centroid 19
# Isochrones calculated for centroid 20
# Isochrones calculated for centroid 21
# Isochrones calculated for centroid 22
# Isochrones calculated for centroid 23
# Isochrones calculated for centroid 24
# Isochrones calculated for centroid 25
# Isochrones calculated for centroid 26
# Isochrones calculated for centroid 27
# Isochrones calculated for centroid 28
# Isochrones calculated for centroid 29
# Isochrones calculated for centroid 30
# Isochrones calculated for centroid 31
# Isochrones calculated for centroid 32
# Isochrones calculated for centroid 33
# Isochrones calculated for centroid 34
# Isochrones calculated for centroid 35
# Isochrones calculated for centroid 36
# Isochrones calculated for centroid 37
# Isochrones calculated for centroid 38
# Isochrones calculated for centroid 39
# Isochrones calculated for centroid 40
# Isochrones calculated for centroid 41
# Isochrones calculated for centroid 42
# Isochrones calculated for centroid 43
# Isochrones calculated for centroid 44
# Isochrones calculated for centroid 45
# Isochrones calculated for centroid 46
# Isochrones calculated for centroid 47
# Isochrones calculated for centroid 48
# Isochrones calculated for centroid 49
# Isochrones calculated for centroid 50
# Isochrones calculated for centroid 51
# Isochrones calculated for centroid 52
# Isochrones calculated for centroid 53
# Isochrones calculated for centroid 54
# Isochrones calculated for centroid 55
# Isochrones calculated for centroid 56
# Isochrones calculated for centroid 57
# Isochrones calculated for centroid 58
# Isochrones calculated for centroid 59
# Isochrones calculated for centroid 60
# Isochrones calculated for centroid 61
# Isochrones calculated for centroid 62
# Isochrones calculated for centroid 63
# Isochrones calculated for centroid 64
# Isochrones calculated for centroid 65
# Isochrones calculated for centroid 66
# Isochrones calculated for centroid 67
# Isochrones calculated for centroid 68
# Isochrones calculated for centroid 69
# Isochrones calculated for centroid 70
# Isochrones calculated for centroid 71
# Isochrones calculated for centroid 72
# Isochrones calculated for centroid 73
# Isochrones calculated for centroid 74
# Isochrones calculated for centroid 75
# Isochrones calculated for centroid 76
# Isochrones calculated for centroid 77
# Isochrones calculated for centroid 78
# Isochrones calculated for centroid 79
# Isochrones calculated for centroid 80
# Isochrones calculated for centroid 81
# Isochrones calculated for centroid 82
# Isochrones calculated for centroid 83
# Isochrones calculated for centroid 84
# Isochrones calculated for centroid 85
# Isochrones calculated for centroid 86
# Isochrones calculated for centroid 87
# Isochrones calculated for centroid 88
# Isochrones calculated for centroid 89
# Isochrones calculated for centroid 90
# Isochrones calculated for centroid 91
# Isochrones calculated for centroid 92
# Isochrones calculated for centroid 93
# Isochrones calculated for centroid 94
# Isochrones calculated for centroid 95
# Isochrones calculated for centroid 96
# Isochrones calculated for centroid 97
# Isochrones calculated for centroid 98
# Isochrones calculated for centroid 99
# Isochrones calculated for centroid 100
# Isochrones calculated for centroid 101
# Isochrones calculated for centroid 102
# Isochrones calculated for centroid 103
# Isochrones calculated for centroid 104
# Isochrones calculated for centroid 105
# Isochrones calculated for centroid 106
# Isochrones calculated for centroid 107
# Isochrones calculated for centroid 108
# Isochrones calculated for centroid 109
# Isochrones calculated for centroid 110
# Isochrones calculated for centroid 111
# Isochrones calculated for centroid 112
# Isochrones calculated for centroid 113
# Isochrones calculated for centroid 114
# Isochrones calculated for centroid 115
# Isochrones calculated for centroid 116
# Isochrones calculated for centroid 117
# Isochrones calculated for centroid 118
# Isochrones calculated for centroid 119
# Isochrones calculated for centroid 120
# Isochrones calculated for centroid 121
# Isochrones calculated for centroid 122
# Isochrones calculated for centroid 123
# Isochrones calculated for centroid 124
# Isochrones calculated for centroid 125
# Isochrones calculated for centroid 126
# Isochrones calculated for centroid 127
# Isochrones calculated for centroid 128
# Isochrones calculated for centroid 129
# Isochrones calculated for centroid 130
# Isochrones calculated for centroid 131
# Isochrones calculated for centroid 132
# Isochrones calculated for centroid 133
# Isochrones calculated for centroid 134
# Isochrones calculated for centroid 135
# Isochrones calculated for centroid 136
# Isochrones calculated for centroid 137
# Isochrones calculated for centroid 138
# Isochrones calculated for centroid 139
# Isochrones calculated for centroid 140
# Isochrones calculated for centroid 141
# Isochrones calculated for centroid 142
# Isochrones calculated for centroid 143
# Isochrones calculated for centroid 144
# Isochrones calculated for centroid 145
# Isochrones calculated for centroid 146
# Isochrones calculated for centroid 147
# Isochrones calculated for centroid 148
# Isochrones calculated for centroid 149
# Isochrones calculated for centroid 150
# Isochrones calculated for centroid 151
# Isochrones calculated for centroid 152
# Isochrones calculated for centroid 153
# Isochrones calculated for centroid 154
# Isochrones calculated for centroid 155
# Isochrones calculated for centroid 156
# Isochrones calculated for centroid 157
# Isochrones calculated for centroid 158
# Isochrones calculated for centroid 159
# Isochrones calculated for centroid 160
# Isochrones calculated for centroid 161
# Isochrones calculated for centroid 162
# Isochrones calculated for centroid 163
# Isochrones calculated for centroid 164
# Isochrones calculated for centroid 165
# Isochrones calculated for centroid 166
# Isochrones calculated for centroid 167
# Isochrones calculated for centroid 168
# Isochrones calculated for centroid 169
# Isochrones calculated for centroid 170
# Isochrones calculated for centroid 171
# Isochrones calculated for centroid 172
# Isochrones calculated for centroid 173
# Isochrones calculated for centroid 174
# Isochrones calculated for centroid 175
# Isochrone calculation for walking completed.

# %%
import geopandas as gpd

# Load power plants GeoJSON file
power_plants = gpd.read_file("../data/output/powerline_distance.geojson")

# Replace the colon (:) with an underscore (_) in the column name
power_plants.columns = power_plants.columns.str.replace(':', '_')

# Print all column names
for col in power_plants.columns:
    print(col)

# Define a function to classify power sources
def classify_power_source(power_source):
    if power_source is not None and any(source in ['solar', 'air', 'wind', 'geothermal', 'hydro', 'wind;battery', 'waste', 'solar;wind', 'biogas'] for source in power_source.split(';')):
        return 10
    elif power_source is not None and any(source in ['biomass', 'coal;biomass', 'biomass;oil', 'gas;solar', 'gas;biomass'] for source in power_source.split(';')):
        return 7
    elif power_source is not None and any(source in ['coal', 'coal;gas', 'coal;gas;biomass', 'coal;oil', 'coal;oil;waste', 'gas', 'gas;oil', 'oil;gas'] for source in power_source.split(';')):
        return 1
    else:
        return 0

# Create a new column "classification" based on "plant_source"
power_plants['classification_powerplant_source'] = power_plants['plant_source'].apply(classify_power_source)

# Print all column names with the new classification column
for col in power_plants.columns:
    print(col)

# Save the modified GeoDataFrame to a new GeoJSON file
power_plants.to_file("../data/output/classified_power_plants.geojson", driver='GeoJSON')
# Out:
# id
# longitude
# latitude
# distance_to_telecom
# nearest_telecom
# distance_to_powerplant
# plant_method
# plant_source
# name
# distance_to_powerline
# cables
# voltage
# geometry
# id
# longitude
# latitude
# distance_to_telecom
# nearest_telecom
# distance_to_powerplant
# plant_method
# plant_source
# name
# distance_to_powerline
# cables
# voltage
# geometry
# classification_powerplant_source

# %%
import geopandas as gpd

# Read the GeoJSON file
gdf = gpd.read_file("../data/output/classified_power_plants.geojson")

# Define a function to classify distances
def classify_distance(distance):
    # Define the range for each class
    class_ranges = [(0, 1000), (1000, 2000), (2000, 3000), (3000, 4000), (4000, 5000),
                    (5000, 6000), (6000, 7000), (7000, 8000), (8000, 9000), (9000, float('inf'))]
    
    # Iterate over class ranges and assign class based on distance
    for i, (start, end) in enumerate(class_ranges, start=1):
        if start <= distance < end:
            return i

# Apply the classification function to create the new column
gdf['classification_powerplant_distance'] = gdf['distance_to_powerplant'].apply(classify_distance)

# Save the GeoDataFrame to a new GeoJSON file
output_file = "../data/output/powerplant_class_distance.geojson"
gdf.to_file(output_file, driver='GeoJSON')

print(f"New GeoJSON file saved as: {output_file}")
# Out:
# New GeoJSON file saved as: ../data/output/powerplant_class_distance.geojson
